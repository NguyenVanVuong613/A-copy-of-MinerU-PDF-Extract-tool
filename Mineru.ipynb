# %% [markdown]
# <a href="https://colab.research.google.com/github/NguyenVanVuong613/PDF_Etracxt/blob/main/Mineru.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # minerU install and use demo

# %% [markdown]
# ## 1.Install

# %% [markdown]
# ### 1.1Using CPU

# %%
# !pip install -U magic-pdf[full] --extra-index-url https://wheels.myhloli.com
# Out:
# Looking in indexes: https://pypi.org/simple, https://wheels.myhloli.com
# Collecting magic-pdf[full]
#   Downloading magic_pdf-0.8.1-py3-none-any.whl.metadata (34 kB)
# Collecting boto3>=1.28.43 (from magic-pdf[full])
#   Downloading boto3-1.35.24-py3-none-any.whl.metadata (6.6 kB)
# Collecting Brotli>=1.1.0 (from magic-pdf[full])
#   Downloading Brotli-1.1.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (5.5 kB)
# Requirement already satisfied: click>=8.1.7 in /usr/local/lib/python3.10/dist-packages (from magic-pdf[full]) (8.1.7)
# Collecting fast-langdetect==0.2.0 (from magic-pdf[full])
#   Downloading fast_langdetect-0.2.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting loguru>=0.6.0 (from magic-pdf[full])
#   Downloading loguru-0.7.2-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: numpy<2.0.0,>=1.21.6 in /usr/local/lib/python3.10/dist-packages (from magic-pdf[full]) (1.26.4)
# Collecting pdfminer.six==20231228 (from magic-pdf[full])
#   Downloading pdfminer.six-20231228-py3-none-any.whl.metadata (4.2 kB)
# Collecting pydantic<2.8.0,>=2.7.2 (from magic-pdf[full])
#   Downloading pydantic-2.7.4-py3-none-any.whl.metadata (109 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.4/109.4 kB 2.5 MB/s eta 0:00:00
# Collecting PyMuPDF>=1.24.9 (from magic-pdf[full])
#   Downloading PyMuPDF-1.24.10-cp310-none-manylinux2014_x86_64.whl.metadata (3.4 kB)
# Requirement already satisfied: scikit-learn>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from magic-pdf[full]) (1.3.2)
# Collecting wordninja>=2.0.0 (from magic-pdf[full])
#   Downloading wordninja-2.0.0.tar.gz (541 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 541.6/541.6 kB 11.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting unimernet==0.1.6 (from magic-pdf[full])
#   Downloading unimernet-0.1.6-py3-none-any.whl.metadata (8.9 kB)
# Collecting ultralytics (from magic-pdf[full])
#   Downloading ultralytics-8.2.99-py3-none-any.whl.metadata (39 kB)
# Collecting paddleocr==2.7.3 (from magic-pdf[full])
#   Downloading paddleocr-2.7.3-py3-none-any.whl.metadata (26 kB)
# Collecting pypandoc (from magic-pdf[full])
#   Downloading pypandoc-1.13-py3-none-any.whl.metadata (16 kB)
# Collecting struct-eqtable==0.1.0 (from magic-pdf[full])
#   Downloading struct_eqtable-0.1.0-py3-none-any.whl.metadata (4.4 kB)
# Collecting detectron2 (from magic-pdf[full])
#   Downloading https://wheels-1251341229.cos.ap-shanghai.myqcloud.com/assets/whl/detectron2/detectron2-0.6-cp310-cp310-linux_x86_64.whl (902 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 902.1/902.1 kB 2.3 MB/s eta 0:00:00
# Collecting paddlepaddle==3.0.0b1 (from magic-pdf[full])
#   Downloading paddlepaddle-3.0.0b1-cp310-cp310-manylinux1_x86_64.whl.metadata (8.6 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from magic-pdf[full]) (3.7.1)
# Collecting fasttext-wheel>=0.9.2 (from fast-langdetect==0.2.0->magic-pdf[full])
#   Downloading fasttext_wheel-0.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (16 kB)
# Collecting robust-downloader>=0.0.2 (from fast-langdetect==0.2.0->magic-pdf[full])
#   Downloading robust_downloader-0.0.2-py3-none-any.whl.metadata (4.1 kB)
# Collecting langdetect>=1.0.9 (from fast-langdetect==0.2.0->magic-pdf[full])
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 58.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: shapely in /usr/local/lib/python3.10/dist-packages (from paddleocr==2.7.3->magic-pdf[full]) (2.0.6)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from paddleocr==2.7.3->magic-pdf[full]) (0.23.2)
# Requirement already satisfied: imgaug in /usr/local/lib/python3.10/dist-packages (from paddleocr==2.7.3->magic-pdf[full]) (0.4.0)
# Collecting pyclipper (from paddleocr==2.7.3->magic-pdf[full])
#   Downloading pyclipper-1.3.0.post5-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (9.0 kB)
# Collecting lmdb (from paddleocr==2.7.3->magic-pdf[full])
#   Downloading lmdb-1.5.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.1 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from paddleocr==2.7.3->magic-pdf[full]) (4.66.5)
# Collecting visualdl (from paddleocr==2.7.3->magic-pdf[full])
#   Downloading visualdl-2.5.3-py3-none-any.whl.metadata (25 kB)
# Collecting rapidfuzz (from paddleocr==2.7.3->magic-pdf[full])
#   Downloading rapidfuzz-3.9.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting opencv-python<=4.6.0.66 (from paddleocr==2.7.3->magic-pdf[full])
#   Downloading opencv_python-4.6.0.66-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Collecting opencv-contrib-python<=4.6.0.66 (from paddleocr==2.7.3->magic-pdf[full])
#   Downloading opencv_contrib_python-4.6.0.66-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Requirement already satisfied: cython in /usr/local/lib/python3.10/dist-packages (from paddleocr==2.7.3->magic-pdf[full]) (3.0.11)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from paddleocr==2.7.3->magic-pdf[full]) (4.9.4)
# Collecting premailer (from paddleocr==2.7.3->magic-pdf[full])
#   Downloading premailer-3.10.0-py2.py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.10/dist-packages (from paddleocr==2.7.3->magic-pdf[full]) (3.1.5)
# Collecting attrdict (from paddleocr==2.7.3->magic-pdf[full])
#   Downloading attrdict-2.0.1-py2.py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: Pillow>=10.0.0 in /usr/local/lib/python3.10/dist-packages (from paddleocr==2.7.3->magic-pdf[full]) (10.4.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from paddleocr==2.7.3->magic-pdf[full]) (6.0.2)
# Collecting python-docx (from paddleocr==2.7.3->magic-pdf[full])
#   Downloading python_docx-1.1.2-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from paddleocr==2.7.3->magic-pdf[full]) (4.12.3)
# Requirement already satisfied: fonttools>=4.24.0 in /usr/local/lib/python3.10/dist-packages (from paddleocr==2.7.3->magic-pdf[full]) (4.53.1)
# Collecting fire>=0.3.0 (from paddleocr==2.7.3->magic-pdf[full])
#   Downloading fire-0.6.0.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.4/88.4 kB 9.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pdf2docx (from paddleocr==2.7.3->magic-pdf[full])
#   Downloading pdf2docx-0.5.8-py3-none-any.whl.metadata (3.2 kB)
# Collecting httpx (from paddlepaddle==3.0.0b1->magic-pdf[full])
#   Downloading httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: protobuf>=3.20.2 in /usr/local/lib/python3.10/dist-packages (from paddlepaddle==3.0.0b1->magic-pdf[full]) (3.20.3)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from paddlepaddle==3.0.0b1->magic-pdf[full]) (4.4.2)
# Collecting astor (from paddlepaddle==3.0.0b1->magic-pdf[full])
#   Downloading astor-0.8.1-py2.py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: opt-einsum==3.3.0 in /usr/local/lib/python3.10/dist-packages (from paddlepaddle==3.0.0b1->magic-pdf[full]) (3.3.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from paddlepaddle==3.0.0b1->magic-pdf[full]) (3.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from paddlepaddle==3.0.0b1->magic-pdf[full]) (4.12.2)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from pdfminer.six==20231228->magic-pdf[full]) (3.3.2)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.10/dist-packages (from pdfminer.six==20231228->magic-pdf[full]) (43.0.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from struct-eqtable==0.1.0->magic-pdf[full]) (2.4.1+cu121)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (from struct-eqtable==0.1.0->magic-pdf[full]) (4.44.2)
# Requirement already satisfied: albumentations<2.0.0,>=1.4.4 in /usr/local/lib/python3.10/dist-packages (from unimernet==0.1.6->magic-pdf[full]) (1.4.15)
# Collecting eva-decord<0.7.0,>=0.6.1 (from unimernet==0.1.6->magic-pdf[full])
#   Downloading eva_decord-0.6.1-py3-none-manylinux2010_x86_64.whl.metadata (449 bytes)
# Collecting evaluate<0.5.0,>=0.4.1 (from unimernet==0.1.6->magic-pdf[full])
#   Downloading evaluate-0.4.3-py3-none-any.whl.metadata (9.2 kB)
# Collecting fairscale<0.5.0,>=0.4.13 (from unimernet==0.1.6->magic-pdf[full])
#   Downloading fairscale-0.4.13.tar.gz (266 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 266.3/266.3 kB 23.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting ftfy<7.0.0,>=6.2.0 (from unimernet==0.1.6->magic-pdf[full])
#   Downloading ftfy-6.2.3-py3-none-any.whl.metadata (7.8 kB)
# Collecting iopath<0.2.0,>=0.1.9 (from unimernet==0.1.6->magic-pdf[full])
#   Downloading iopath-0.1.10.tar.gz (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 4.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting matplotlib (from magic-pdf[full])
#   Downloading matplotlib-3.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting omegaconf<3.0.0,>=2.3.0 (from unimernet==0.1.6->magic-pdf[full])
#   Downloading omegaconf-2.3.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting timm<0.10.0,>=0.9.16 (from unimernet==0.1.6->magic-pdf[full])
#   Downloading timm-0.9.16-py3-none-any.whl.metadata (38 kB)
# Collecting torch (from struct-eqtable==0.1.0->magic-pdf[full])
#   Downloading torch-2.3.1-cp310-cp310-manylinux1_x86_64.whl.metadata (26 kB)
# Collecting torchtext<=0.18.0,>=0.17.2 (from unimernet==0.1.6->magic-pdf[full])
#   Downloading torchtext-0.18.0-cp310-cp310-manylinux1_x86_64.whl.metadata (7.9 kB)
# Collecting torchvision<=0.18.1,>=0.17.2 (from unimernet==0.1.6->magic-pdf[full])
#   Downloading torchvision-0.18.1-cp310-cp310-manylinux1_x86_64.whl.metadata (6.6 kB)
# Collecting transformers (from struct-eqtable==0.1.0->magic-pdf[full])
#   Downloading transformers-4.40.0-py3-none-any.whl.metadata (137 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.6/137.6 kB 11.3 MB/s eta 0:00:00
# Collecting wand<0.7.0,>=0.6.13 (from unimernet==0.1.6->magic-pdf[full])
#   Downloading Wand-0.6.13-py2.py3-none-any.whl.metadata (4.0 kB)
# Collecting webdataset<0.3.0,>=0.2.86 (from unimernet==0.1.6->magic-pdf[full])
#   Downloading webdataset-0.2.100-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers->struct-eqtable==0.1.0->magic-pdf[full]) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers->struct-eqtable==0.1.0->magic-pdf[full]) (0.24.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers->struct-eqtable==0.1.0->magic-pdf[full]) (24.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers->struct-eqtable==0.1.0->magic-pdf[full]) (2024.9.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers->struct-eqtable==0.1.0->magic-pdf[full]) (2.32.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers->struct-eqtable==0.1.0->magic-pdf[full]) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers->struct-eqtable==0.1.0->magic-pdf[full]) (0.4.5)
# Collecting botocore<1.36.0,>=1.35.24 (from boto3>=1.28.43->magic-pdf[full])
#   Downloading botocore-1.35.24-py3-none-any.whl.metadata (5.7 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3>=1.28.43->magic-pdf[full])
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.11.0,>=0.10.0 (from boto3>=1.28.43->magic-pdf[full])
#   Downloading s3transfer-0.10.2-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->magic-pdf[full]) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->magic-pdf[full]) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->magic-pdf[full]) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->magic-pdf[full]) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->magic-pdf[full]) (2.8.2)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<2.8.0,>=2.7.2->magic-pdf[full]) (0.7.0)
# Collecting pydantic-core==2.18.4 (from pydantic<2.8.0,>=2.7.2->magic-pdf[full])
#   Downloading pydantic_core-2.18.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.5 kB)
# Collecting PyMuPDFb==1.24.10 (from PyMuPDF>=1.24.9->magic-pdf[full])
#   Downloading PyMuPDFb-1.24.10-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.4 kB)
# Requirement already satisfied: scipy>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.2->magic-pdf[full]) (1.13.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.2->magic-pdf[full]) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.2->magic-pdf[full]) (3.5.0)
# Requirement already satisfied: pycocotools>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from detectron2->magic-pdf[full]) (2.0.8)
# Requirement already satisfied: termcolor>=1.1 in /usr/local/lib/python3.10/dist-packages (from detectron2->magic-pdf[full]) (2.4.0)
# Collecting yacs>=0.1.8 (from detectron2->magic-pdf[full])
#   Downloading yacs-0.1.8-py3-none-any.whl.metadata (639 bytes)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from detectron2->magic-pdf[full]) (0.9.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from detectron2->magic-pdf[full]) (2.2.1)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.10/dist-packages (from detectron2->magic-pdf[full]) (2.17.0)
# Collecting fvcore<0.1.6,>=0.1.5 (from detectron2->magic-pdf[full])
#   Downloading fvcore-0.1.5.post20221221.tar.gz (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 4.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting iopath<0.2.0,>=0.1.9 (from unimernet==0.1.6->magic-pdf[full])
#   Downloading iopath-0.1.9-py3-none-any.whl.metadata (370 bytes)
# Collecting hydra-core>=1.1 (from detectron2->magic-pdf[full])
#   Downloading hydra_core-1.3.2-py3-none-any.whl.metadata (5.5 kB)
# Collecting black (from detectron2->magic-pdf[full])
#   Downloading black-24.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl.metadata (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.2/78.2 kB 7.0 MB/s eta 0:00:00
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ultralytics->magic-pdf[full]) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from ultralytics->magic-pdf[full]) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.10/dist-packages (from ultralytics->magic-pdf[full]) (2.1.4)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics->magic-pdf[full]) (0.13.1)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics->magic-pdf[full])
#   Downloading ultralytics_thop-2.0.8-py3-none-any.whl.metadata (9.3 kB)
# Requirement already satisfied: albucore>=0.0.15 in /usr/local/lib/python3.10/dist-packages (from albumentations<2.0.0,>=1.4.4->unimernet==0.1.6->magic-pdf[full]) (0.0.16)
# Requirement already satisfied: eval-type-backport in /usr/local/lib/python3.10/dist-packages (from albumentations<2.0.0,>=1.4.4->unimernet==0.1.6->magic-pdf[full]) (0.2.0)
# Requirement already satisfied: opencv-python-headless>=4.9.0.80 in /usr/local/lib/python3.10/dist-packages (from albumentations<2.0.0,>=1.4.4->unimernet==0.1.6->magic-pdf[full]) (4.10.0.84)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /usr/local/lib/python3.10/dist-packages (from botocore<1.36.0,>=1.35.24->boto3>=1.28.43->magic-pdf[full]) (2.0.7)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=36.0.0->pdfminer.six==20231228->magic-pdf[full]) (1.17.1)
# Collecting datasets>=2.0.0 (from evaluate<0.5.0,>=0.4.1->unimernet==0.1.6->magic-pdf[full])
#   Downloading datasets-3.0.0-py3-none-any.whl.metadata (19 kB)
# Collecting dill (from evaluate<0.5.0,>=0.4.1->unimernet==0.1.6->magic-pdf[full])
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Collecting xxhash (from evaluate<0.5.0,>=0.4.1->unimernet==0.1.6->magic-pdf[full])
#   Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess (from evaluate<0.5.0,>=0.4.1->unimernet==0.1.6->magic-pdf[full])
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: fsspec>=2021.05.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>=2021.05.0->evaluate<0.5.0,>=0.4.1->unimernet==0.1.6->magic-pdf[full]) (2024.6.1)
# Collecting pybind11>=2.2 (from fasttext-wheel>=0.9.2->fast-langdetect==0.2.0->magic-pdf[full])
#   Downloading pybind11-2.13.6-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: setuptools>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from fasttext-wheel>=0.9.2->fast-langdetect==0.2.0->magic-pdf[full]) (71.0.4)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from fire>=0.3.0->paddleocr==2.7.3->magic-pdf[full]) (1.16.0)
# Requirement already satisfied: wcwidth<0.3.0,>=0.2.12 in /usr/local/lib/python3.10/dist-packages (from ftfy<7.0.0,>=6.2.0->unimernet==0.1.6->magic-pdf[full]) (0.2.13)
# Collecting antlr4-python3-runtime==4.9.* (from hydra-core>=1.1->detectron2->magic-pdf[full])
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 11.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting portalocker (from iopath<0.2.0,>=0.1.9->unimernet==0.1.6->magic-pdf[full])
#   Downloading portalocker-2.10.1-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics->magic-pdf[full]) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics->magic-pdf[full]) (2024.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->struct-eqtable==0.1.0->magic-pdf[full]) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->struct-eqtable==0.1.0->magic-pdf[full]) (2024.8.30)
# Collecting colorlog (from robust-downloader>=0.0.2->fast-langdetect==0.2.0->magic-pdf[full])
#   Downloading colorlog-6.8.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: imageio>=2.33 in /usr/local/lib/python3.10/dist-packages (from scikit-image->paddleocr==2.7.3->magic-pdf[full]) (2.35.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.10/dist-packages (from scikit-image->paddleocr==2.7.3->magic-pdf[full]) (2024.8.30)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.10/dist-packages (from scikit-image->paddleocr==2.7.3->magic-pdf[full]) (0.4)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->struct-eqtable==0.1.0->magic-pdf[full]) (1.13.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->struct-eqtable==0.1.0->magic-pdf[full]) (3.1.4)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch->struct-eqtable==0.1.0->magic-pdf[full])
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch->struct-eqtable==0.1.0->magic-pdf[full])
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch->struct-eqtable==0.1.0->magic-pdf[full])
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch->struct-eqtable==0.1.0->magic-pdf[full])
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch->struct-eqtable==0.1.0->magic-pdf[full])
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch->struct-eqtable==0.1.0->magic-pdf[full])
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch->struct-eqtable==0.1.0->magic-pdf[full])
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch->struct-eqtable==0.1.0->magic-pdf[full])
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch->struct-eqtable==0.1.0->magic-pdf[full])
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch->struct-eqtable==0.1.0->magic-pdf[full])
#   Downloading nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch->struct-eqtable==0.1.0->magic-pdf[full])
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Collecting triton==2.3.1 (from torch->struct-eqtable==0.1.0->magic-pdf[full])
#   Downloading triton-2.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.4 kB)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch->struct-eqtable==0.1.0->magic-pdf[full])
#   Downloading nvidia_nvjitlink_cu12-12.6.68-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting braceexpand (from webdataset<0.3.0,>=0.2.86->unimernet==0.1.6->magic-pdf[full])
#   Downloading braceexpand-0.1.7-py2.py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->paddleocr==2.7.3->magic-pdf[full]) (2.6)
# Collecting mypy-extensions>=0.4.3 (from black->detectron2->magic-pdf[full])
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting pathspec>=0.9.0 (from black->detectron2->magic-pdf[full])
#   Downloading pathspec-0.12.1-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: platformdirs>=2 in /usr/local/lib/python3.10/dist-packages (from black->detectron2->magic-pdf[full]) (4.3.6)
# Requirement already satisfied: tomli>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from black->detectron2->magic-pdf[full]) (2.0.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx->paddlepaddle==3.0.0b1->magic-pdf[full]) (3.7.1)
# Collecting httpcore==1.* (from httpx->paddlepaddle==3.0.0b1->magic-pdf[full])
#   Downloading httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx->paddlepaddle==3.0.0b1->magic-pdf[full]) (1.3.1)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx->paddlepaddle==3.0.0b1->magic-pdf[full])
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.10/dist-packages (from openpyxl->paddleocr==2.7.3->magic-pdf[full]) (1.1.0)
# Collecting cssselect (from premailer->paddleocr==2.7.3->magic-pdf[full])
#   Downloading cssselect-1.2.0-py2.py3-none-any.whl.metadata (2.2 kB)
# Collecting cssutils (from premailer->paddleocr==2.7.3->magic-pdf[full])
#   Downloading cssutils-2.11.1-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.10/dist-packages (from premailer->paddleocr==2.7.3->magic-pdf[full]) (5.5.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2->magic-pdf[full]) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2->magic-pdf[full]) (1.64.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2->magic-pdf[full]) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2->magic-pdf[full]) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2->magic-pdf[full]) (3.0.4)
# Collecting bce-python-sdk (from visualdl->paddleocr==2.7.3->magic-pdf[full])
#   Downloading bce_python_sdk-0.9.22-py3-none-any.whl.metadata (319 bytes)
# Requirement already satisfied: flask>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from visualdl->paddleocr==2.7.3->magic-pdf[full]) (2.2.5)
# Collecting Flask-Babel>=3.0.0 (from visualdl->paddleocr==2.7.3->magic-pdf[full])
#   Downloading flask_babel-4.0.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting rarfile (from visualdl->paddleocr==2.7.3->magic-pdf[full])
#   Downloading rarfile-4.2-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20231228->magic-pdf[full]) (2.22)
# Collecting pyarrow>=15.0.0 (from datasets>=2.0.0->evaluate<0.5.0,>=0.4.1->unimernet==0.1.6->magic-pdf[full])
#   Downloading pyarrow-17.0.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (3.3 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate<0.5.0,>=0.4.1->unimernet==0.1.6->magic-pdf[full]) (3.10.5)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.10/dist-packages (from flask>=1.1.1->visualdl->paddleocr==2.7.3->magic-pdf[full]) (2.2.0)
# Requirement already satisfied: Babel>=2.12 in /usr/local/lib/python3.10/dist-packages (from Flask-Babel>=3.0.0->visualdl->paddleocr==2.7.3->magic-pdf[full]) (2.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->struct-eqtable==0.1.0->magic-pdf[full]) (2.1.5)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx->paddlepaddle==3.0.0b1->magic-pdf[full]) (1.2.2)
# Collecting pycryptodome>=3.8.0 (from bce-python-sdk->visualdl->paddleocr==2.7.3->magic-pdf[full])
#   Downloading pycryptodome-3.20.0-cp35-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.4 kB)
# Requirement already satisfied: future>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from bce-python-sdk->visualdl->paddleocr==2.7.3->magic-pdf[full]) (1.0.0)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.10/dist-packages (from cssutils->premailer->paddleocr==2.7.3->magic-pdf[full]) (10.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->struct-eqtable==0.1.0->magic-pdf[full]) (1.3.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate<0.5.0,>=0.4.1->unimernet==0.1.6->magic-pdf[full]) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate<0.5.0,>=0.4.1->unimernet==0.1.6->magic-pdf[full]) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate<0.5.0,>=0.4.1->unimernet==0.1.6->magic-pdf[full]) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate<0.5.0,>=0.4.1->unimernet==0.1.6->magic-pdf[full]) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate<0.5.0,>=0.4.1->unimernet==0.1.6->magic-pdf[full]) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate<0.5.0,>=0.4.1->unimernet==0.1.6->magic-pdf[full]) (1.11.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate<0.5.0,>=0.4.1->unimernet==0.1.6->magic-pdf[full]) (4.0.3)
# Downloading fast_langdetect-0.2.0-py3-none-any.whl (6.4 kB)
# Downloading paddleocr-2.7.3-py3-none-any.whl (780 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 780.0/780.0 kB 47.7 MB/s eta 0:00:00
# Downloading paddlepaddle-3.0.0b1-cp310-cp310-manylinux1_x86_64.whl (141.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.8/141.8 MB 7.1 MB/s eta 0:00:00
# Downloading pdfminer.six-20231228-py3-none-any.whl (5.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 93.1 MB/s eta 0:00:00
# Downloading struct_eqtable-0.1.0-py3-none-any.whl (8.5 kB)
# Downloading unimernet-0.1.6-py3-none-any.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 80.1 MB/s eta 0:00:00
# Downloading transformers-4.40.0-py3-none-any.whl (9.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.0/9.0 MB 119.3 MB/s eta 0:00:00
# Downloading boto3-1.35.24-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.2/139.2 kB 12.9 MB/s eta 0:00:00
# Downloading Brotli-1.1.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 101.3 MB/s eta 0:00:00
# Downloading loguru-0.7.2-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 6.1 MB/s eta 0:00:00
# Downloading matplotlib-3.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 110.1 MB/s eta 0:00:00
# Downloading pydantic-2.7.4-py3-none-any.whl (409 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 409.0/409.0 kB 37.7 MB/s eta 0:00:00
# Downloading pydantic_core-2.18.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 13.3 MB/s eta 0:00:00
# Downloading PyMuPDF-1.24.10-cp310-none-manylinux2014_x86_64.whl (3.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 96.9 MB/s eta 0:00:00
# Downloading PyMuPDFb-1.24.10-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (15.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 55.0 MB/s eta 0:00:00
# Downloading magic_pdf-0.8.1-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 65.7 MB/s eta 0:00:00
# Downloading pypandoc-1.13-py3-none-any.whl (21 kB)
# Downloading ultralytics-8.2.99-py3-none-any.whl (874 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 874.0/874.0 kB 60.7 MB/s eta 0:00:00
# Downloading botocore-1.35.24-py3-none-any.whl (12.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.6/12.6 MB 118.2 MB/s eta 0:00:00
# Downloading eva_decord-0.6.1-py3-none-manylinux2010_x86_64.whl (13.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.6/13.6 MB 78.6 MB/s eta 0:00:00
# Downloading evaluate-0.4.3-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 8.2 MB/s eta 0:00:00
# Downloading fasttext_wheel-0.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 56.7 MB/s eta 0:00:00
# Downloading ftfy-6.2.3-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.0/43.0 kB 4.0 MB/s eta 0:00:00
# Downloading hydra_core-1.3.2-py3-none-any.whl (154 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 15.9 MB/s eta 0:00:00
# Downloading iopath-0.1.9-py3-none-any.whl (27 kB)
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 8.6 MB/s eta 0:00:00
# Downloading opencv_contrib_python-4.6.0.66-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (67.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.1/67.1 MB 10.1 MB/s eta 0:00:00
# Downloading opencv_python-4.6.0.66-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (60.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.9/60.9 MB 19.3 MB/s eta 0:00:00
# Downloading rapidfuzz-3.9.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 93.8 MB/s eta 0:00:00
# Downloading robust_downloader-0.0.2-py3-none-any.whl (15 kB)
# Downloading s3transfer-0.10.2-py3-none-any.whl (82 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.7/82.7 kB 8.2 MB/s eta 0:00:00
# Downloading timm-0.9.16-py3-none-any.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 90.7 MB/s eta 0:00:00
# Downloading torch-2.3.1-cp310-cp310-manylinux1_x86_64.whl (779.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 779.1/779.1 MB 1.4 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 4.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 64.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 37.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 47.7 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.8 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 7.9 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 12.7 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 7.6 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 5.4 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.2/176.2 MB 7.0 MB/s eta 0:00:00
# Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 10.3 MB/s eta 0:00:00
# Downloading triton-2.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (168.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.1/168.1 MB 7.1 MB/s eta 0:00:00
# Downloading torchtext-0.18.0-cp310-cp310-manylinux1_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 9.8 MB/s eta 0:00:00
# Downloading torchvision-0.18.1-cp310-cp310-manylinux1_x86_64.whl (7.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 30.1 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.8-py3-none-any.whl (26 kB)
# Downloading Wand-0.6.13-py2.py3-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.8/143.8 kB 5.6 MB/s eta 0:00:00
# Downloading webdataset-0.2.100-py3-none-any.whl (74 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.8/74.8 kB 7.9 MB/s eta 0:00:00
# Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Downloading astor-0.8.1-py2.py3-none-any.whl (27 kB)
# Downloading attrdict-2.0.1-py2.py3-none-any.whl (9.9 kB)
# Downloading black-24.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 79.9 MB/s eta 0:00:00
# Downloading httpx-0.27.2-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 8.6 MB/s eta 0:00:00
# Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 7.9 MB/s eta 0:00:00
# Downloading lmdb-1.5.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 27.8 MB/s eta 0:00:00
# Downloading pdf2docx-0.5.8-py3-none-any.whl (132 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.0/132.0 kB 13.7 MB/s eta 0:00:00
# Downloading python_docx-1.1.2-py3-none-any.whl (244 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.3/244.3 kB 25.9 MB/s eta 0:00:00
# Downloading premailer-3.10.0-py2.py3-none-any.whl (19 kB)
# Downloading pyclipper-1.3.0.post5-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (908 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 908.3/908.3 kB 56.7 MB/s eta 0:00:00
# Downloading visualdl-2.5.3-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 117.1 MB/s eta 0:00:00
# Downloading datasets-3.0.0-py3-none-any.whl (474 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 474.3/474.3 kB 35.8 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 13.3 MB/s eta 0:00:00
# Downloading flask_babel-4.0.0-py3-none-any.whl (9.6 kB)
# Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Downloading pathspec-0.12.1-py3-none-any.whl (31 kB)
# Downloading pybind11-2.13.6-py3-none-any.whl (243 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.3/243.3 kB 24.3 MB/s eta 0:00:00
# Downloading bce_python_sdk-0.9.22-py3-none-any.whl (336 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 336.6/336.6 kB 31.0 MB/s eta 0:00:00
# Downloading braceexpand-0.1.7-py2.py3-none-any.whl (5.9 kB)
# Downloading colorlog-6.8.2-py3-none-any.whl (11 kB)
# Downloading cssselect-1.2.0-py2.py3-none-any.whl (18 kB)
# Downloading cssutils-2.11.1-py3-none-any.whl (385 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 385.7/385.7 kB 34.2 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 16.6 MB/s eta 0:00:00
# Downloading portalocker-2.10.1-py3-none-any.whl (18 kB)
# Downloading rarfile-4.2-py3-none-any.whl (29 kB)
# Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 20.2 MB/s eta 0:00:00
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.2 MB/s eta 0:00:00
# Downloading pyarrow-17.0.0-cp310-cp310-manylinux_2_28_x86_64.whl (39.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.9/39.9 MB 18.1 MB/s eta 0:00:00
# Downloading pycryptodome-3.20.0-cp35-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 94.0 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.6.68-py3-none-manylinux2014_x86_64.whl (19.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 96.7 MB/s eta 0:00:00
# Building wheels for collected packages: wordninja, fairscale, fire, fvcore, antlr4-python3-runtime, langdetect
#   Building wheel for wordninja (setup.py) ... done
#   Created wheel for wordninja: filename=wordninja-2.0.0-py3-none-any.whl size=541530 sha256=c021c894ec8f3aa25adb990b1f6efef035afca2561bfcf2cd456b2480e25cce3
#   Stored in directory: /root/.cache/pip/wheels/aa/44/3a/f2a5c1859b8b541ded969b4cd12d0a58897f12408f4f51e084
#   Building wheel for fairscale (pyproject.toml) ... done
#   Created wheel for fairscale: filename=fairscale-0.4.13-py3-none-any.whl size=332106 sha256=33d5002f25cc9ae7b507bab8749d42d66e99675381e6f8e08a880491e9be281a
#   Stored in directory: /root/.cache/pip/wheels/78/a4/c0/fb0a7ef03cff161611c3fa40c6cf898f76e58ec421b88e8cb3
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.6.0-py2.py3-none-any.whl size=117030 sha256=3e84114daaafbac720644920d89f541627235b3b955258ee6b3ac2d23d5f8dda
#   Stored in directory: /root/.cache/pip/wheels/d6/6d/5d/5b73fa0f46d01a793713f8859201361e9e581ced8c75e5c6a3
#   Building wheel for fvcore (setup.py) ... done
#   Created wheel for fvcore: filename=fvcore-0.1.5.post20221221-py3-none-any.whl size=61395 sha256=289ec75b4e29f3322d35ac76aa6b5fb2f580180b2569db2b14913f0a92aaabe7
#   Stored in directory: /root/.cache/pip/wheels/01/c0/af/77c1cf53a1be9e42a52b48e5af2169d40ec2e89f7362489dd0
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144554 sha256=63ab378abef3db86259efeaaf522247c85276f98b689c3c6098362859076b982
#   Stored in directory: /root/.cache/pip/wheels/12/93/dd/1f6a127edc45659556564c5730f6d4e300888f4bca2d4c5a88
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993221 sha256=0d6584fd5c73c87ea21281862e970d7da8b4cbb7c207320eff37f940f538835e
#   Stored in directory: /root/.cache/pip/wheels/95/03/7d/59ea870c70ce4e5a370638b5462a7711ab78fba2f655d05106
# Successfully built wordninja fairscale fire fvcore antlr4-python3-runtime langdetect
# Installing collected packages: wordninja, wand, pyclipper, lmdb, Brotli, braceexpand, antlr4-python3-runtime, yacs, xxhash, webdataset, triton, rarfile, rapidfuzz, python-docx, pypandoc, PyMuPDFb, pydantic-core, pycryptodome, pybind11, pyarrow, portalocker, pathspec, opencv-python, opencv-contrib-python, omegaconf, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, mypy-extensions, loguru, langdetect, jmespath, h11, ftfy, fire, eva-decord, dill, cssutils, cssselect, colorlog, attrdict, astor, robust-downloader, PyMuPDF, pydantic, premailer, nvidia-cusparse-cu12, nvidia-cudnn-cu12, multiprocess, matplotlib, iopath, hydra-core, httpcore, fasttext-wheel, botocore, black, bce-python-sdk, s3transfer, pdfminer.six, pdf2docx, nvidia-cusolver-cu12, httpx, fvcore, Flask-Babel, fast-langdetect, visualdl, transformers, torch, paddlepaddle, detectron2, boto3, ultralytics-thop, torchvision, torchtext, struct-eqtable, paddleocr, magic-pdf, fairscale, datasets, ultralytics, timm, evaluate, unimernet
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.23.4
#     Uninstalling pydantic_core-2.23.4:
#       Successfully uninstalled pydantic_core-2.23.4
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 14.0.2
#     Uninstalling pyarrow-14.0.2:
#       Successfully uninstalled pyarrow-14.0.2
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.10.0.84
#     Uninstalling opencv-python-4.10.0.84:
#       Successfully uninstalled opencv-python-4.10.0.84
#   Attempting uninstall: opencv-contrib-python
#     Found existing installation: opencv-contrib-python 4.10.0.84
#     Uninstalling opencv-contrib-python-4.10.0.84:
#       Successfully uninstalled opencv-contrib-python-4.10.0.84
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.23.4
#     Uninstalling nvidia-nccl-cu12-2.23.4:
#       Successfully uninstalled nvidia-nccl-cu12-2.23.4
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.9.2
#     Uninstalling pydantic-2.9.2:
#       Successfully uninstalled pydantic-2.9.2
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.7.1
#     Uninstalling matplotlib-3.7.1:
#       Successfully uninstalled matplotlib-3.7.1
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.44.2
#     Uninstalling transformers-4.44.2:
#       Successfully uninstalled transformers-4.44.2
#   Attempting uninstall: torch
#     Found existing installation: torch 2.4.1+cu121
#     Uninstalling torch-2.4.1+cu121:
#       Successfully uninstalled torch-2.4.1+cu121
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.19.1+cu121
#     Uninstalling torchvision-0.19.1+cu121:
#       Successfully uninstalled torchvision-0.19.1+cu121
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 24.4.1 requires pyarrow<15.0.0a0,>=14.0.1, but you have pyarrow 17.0.0 which is incompatible.
# ibis-framework 8.0.0 requires pyarrow<16,>=2, but you have pyarrow 17.0.0 which is incompatible.
# torchaudio 2.4.1+cu121 requires torch==2.4.1, but you have torch 2.3.1 which is incompatible.
# Successfully installed Brotli-1.1.0 Flask-Babel-4.0.0 PyMuPDF-1.24.10 PyMuPDFb-1.24.10 antlr4-python3-runtime-4.9.3 astor-0.8.1 attrdict-2.0.1 bce-python-sdk-0.9.22 black-24.8.0 boto3-1.35.24 botocore-1.35.24 braceexpand-0.1.7 colorlog-6.8.2 cssselect-1.2.0 cssutils-2.11.1 datasets-3.0.0 detectron2-0.6 dill-0.3.8 eva-decord-0.6.1 evaluate-0.4.3 fairscale-0.4.13 fast-langdetect-0.2.0 fasttext-wheel-0.9.2 fire-0.6.0 ftfy-6.2.3 fvcore-0.1.5.post20221221 h11-0.14.0 httpcore-1.0.5 httpx-0.27.2 hydra-core-1.3.2 iopath-0.1.9 jmespath-1.0.1 langdetect-1.0.9 lmdb-1.5.1 loguru-0.7.2 magic-pdf-0.8.1 matplotlib-3.9.2 multiprocess-0.70.16 mypy-extensions-1.0.0 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.6.68 nvidia-nvtx-cu12-12.1.105 omegaconf-2.3.0 opencv-contrib-python-4.6.0.66 opencv-python-4.6.0.66 paddleocr-2.7.3 paddlepaddle-3.0.0b1 pathspec-0.12.1 pdf2docx-0.5.8 pdfminer.six-20231228 portalocker-2.10.1 premailer-3.10.0 pyarrow-17.0.0 pybind11-2.13.6 pyclipper-1.3.0.post5 pycryptodome-3.20.0 pydantic-2.7.4 pydantic-core-2.18.4 pypandoc-1.13 python-docx-1.1.2 rapidfuzz-3.9.7 rarfile-4.2 robust-downloader-0.0.2 s3transfer-0.10.2 struct-eqtable-0.1.0 timm-0.9.16 torch-2.3.1 torchtext-0.18.0 torchvision-0.18.1 transformers-4.40.0 triton-2.3.1 ultralytics-8.2.99 ultralytics-thop-2.0.8 unimernet-0.1.6 visualdl-2.5.3 wand-0.6.13 webdataset-0.2.100 wordninja-2.0.0 xxhash-3.5.0 yacs-0.1.8

# %%
# !magic-pdf -v
# Out:
# magic-pdf, version 0.8.1

# %%
#!wget https://github.com/opendatalab/MinerU/raw/master/docs/download_models_hf.py && pip install huggingface_hub

# %%
#from huggingface_hub import snapshot_download
#model_dir = snapshot_download('opendatalab/PDF-Extract-Kit')
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Fetching 31 files:   0%|          | 0/31 [00:00<?, ?it/s]

# %%
# !git lfs install
# Out:
# Git LFS initialized.

# %%
# !git lfs clone https://huggingface.co/opendatalab/PDF-Extract-Kit

# %%
"""
move magic-pdf.template.json under root/
modify "models-dir" in magic-pdf.json
"""
# !wget https://github.com/opendatalab/MinerU/raw/master/magic-pdf.template.json && mv magic-pdf.template.json ~/magic-pdf.json && sed -i 's|/tmp/models|{model_dir}|g' ~/magic-pdf.json

# %% [markdown]
# ### 1.2Using GPU

# %%
# !sed -i 's|cpu|cuda|g' ~/magic-pdf.json

# %%
# !pip install paddlepaddle-gpu==3.0.0b1 -i https://www.paddlepaddle.org.cn/packages/stable/cu118/

# %% [markdown]
# ## 2.Usage

# %% [markdown]
# ### 2.1Command line

# %% [markdown]
# #### **Convert Single PDF**

# %%
# !wget https://github.com/opendatalab/MinerU/raw/master/demo/demo1.pdf && wget https://github.com/opendatalab/MinerU/raw/master/demo/demo2.pdf

# %%
# !magic-pdf -p /content/test3.pdf -o output2/ -m auto

# %%
import os
from PIL import Image
from loguru import logger

from magic_pdf.model import pdf_extract_kit

output_dir = '/content/output_formulas'  # This is within Colab's file system

# Create the directory if it doesn't exist
os.makedirs(output_dir, exist_ok=True)

# Save mf_image_list to the output directory
for idx, img in enumerate(mf_image_list):
    image_filename = os.path.join(output_dir, f"formula_{idx}.png")
    img.save(image_filename)
    print(f"Saved formula image to {image_filename}")

# %%
import fitz  # PyMuPDF
import matplotlib.pyplot as plt


import fitz  # PyMuPDF
import matplotlib.pyplot as plt
import numpy as np

# Open the PDF file
# Open the PDF file
layout = "output/demo1/auto/layout.pdf"
spans = "output/demo1/auto/spans.pdf"
# Load and render the first page
layout_page_0 = fitz.open(layout).load_page(0)
spans_page_0 = fitz.open(spans).load_page(0)


pix1 = layout_page_0.get_pixmap()
img_array1 = np.frombuffer(pix1.samples, dtype=np.uint8).reshape(pix1.height, pix1.width, pix1.n)

# Load and render the second page
pix2 = spans_page_0.get_pixmap()
img_array2 = np.frombuffer(pix2.samples, dtype=np.uint8).reshape(pix2.height, pix2.width, pix2.n)

# Create subplots
fig, axes = plt.subplots(1, 2, figsize=(12, 8))

# Display the first image
axes[0].imshow(img_array1)
axes[0].axis('off')

# Display the second image
axes[1].imshow(img_array2)
axes[1].axis('off')

plt.tight_layout()
plt.show()

# %%
# !pip install pypandoc reportlab pdfplumber

# %%
# Install necessary Python libraries
# !pip install pypandoc reportlab pdfplumber

# Install wkhtmltopdf as the PDF engine
# !apt-get install -y wkhtmltopdf

# %%
# Import necessary libraries
import pypandoc
from reportlab.lib.pagesizes import A4
from reportlab.pdfgen import canvas
import pdfplumber

# Convert markdown (demo1.md) to a new PDF using pypandoc
md_input = "/content/output/demo1/auto/demo1.md"
pdf_output = "/content/output/demo1/auto/reconstructed_pdf_from_md.pdf"

# Convert markdown to PDF
pypandoc.convert_file(md_input, 'pdf', outputfile=pdf_output)
print(f"PDF generated from markdown: {pdf_output}")

# Open and extract content from demo1_layout.pdf using pdfplumber
layout_pdf_path = "/content/output/demo1/auto/demo1_layout.pdf"
new_pdf_with_layout = "/content/output/demo1/auto/new_pdf_with_layout.pdf"

with pdfplumber.open(layout_pdf_path) as pdf:
    first_page = pdf.pages[0]  # Example: Get the first page
    extracted_text = first_page.extract_text()  # Extract text from the page
    print("Extracted Text from Layout PDF:")
    print(extracted_text)

    # Generate a new PDF by combining markdown content with layout content
    c = canvas.Canvas(new_pdf_with_layout, pagesize=A4)

    # Add text from markdown (already converted to PDF)
    c.drawString(100, 800, "Text extracted from markdown...")

    # Add content extracted from the layout PDF
    c.drawString(100, 750, "Text extracted from layout PDF:")
    c.drawString(100, 725, extracted_text[:1000])  # Add a portion of the extracted text

    # You can add more content such as images, tables, etc., from layout or other sources here.

    c.showPage()
    c.save()

print(f"New PDF with content from layout and markdown: {new_pdf_with_layout}")

# %% [markdown]
# #### **Convert Batch PDF**

# %%
# !find ./ -name "*.pdf" | xargs -I {} magic-pdf -p {} -o output/
# Out:
# 2024-08-30 09:43:43.128 | INFO     | magic_pdf.libs.pdf_check:detect_invalid_chars:57 - cid_count: 0, text_len: 5803, cid_chars_radio: 0.0
# 2024-08-30 09:43:57.774 | INFO     | magic_pdf.model.pdf_extract_kit:__init__:111 - DocAnalysis init, this may take some times. apply_layout: True, apply_formula: True, apply_ocr: False, apply_table: False
# 2024-08-30 09:43:57.774 | INFO     | magic_pdf.model.pdf_extract_kit:__init__:119 - using device: cuda
# 2024-08-30 09:43:57.774 | INFO     | magic_pdf.model.pdf_extract_kit:__init__:121 - using models_dir: /content/PDF-Extract-Kit/models
# CustomVisionEncoderDecoderModel init
# CustomMBartForCausalLM init
# CustomMBartDecoder init
# [08/30 09:44:36 detectron2]: Rank of current process: 0. World size: 1
# [08/30 09:44:37 detectron2]: Environment info:
# -------------------------------  -----------------------------------------------------------------
# sys.platform                     linux
# Python                           3.10.12 (main, Jul 29 2024, 16:56:48) [GCC 11.4.0]
# numpy                            1.26.3
# detectron2                       0.6 @/usr/local/lib/python3.10/dist-packages/detectron2
# Compiler                         GCC 11.4
# CUDA compiler                    not available
# DETECTRON2_ENV_MODULE            <not set>
# PyTorch                          2.3.1+cu118 @/usr/local/lib/python3.10/dist-packages/torch
# PyTorch debug build              False
# torch._C._GLIBCXX_USE_CXX11_ABI  False
# GPU available                    Yes
# GPU 0                            Tesla T4 (arch=7.5)
# Driver version                   535.104.05
# CUDA_HOME                        /usr/local/cuda
# Pillow                           10.2.0
# torchvision                      0.18.1+cu118 @/usr/local/lib/python3.10/dist-packages/torchvision
# torchvision arch flags           3.5, 5.0, 6.0, 7.0, 7.5, 8.0, 8.6
# fvcore                           0.1.5.post20221221
# iopath                           0.1.9
# cv2                              4.6.0
# -------------------------------  -----------------------------------------------------------------
# PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v3.3.6 (Git Hash 86e6af5974177e513fd3fee58425e1063e7f1361)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX512
#   - CUDA Runtime 11.8
#   - NVCC architecture flags: -gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_90,code=sm_90
#   - CuDNN 8.7
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.8, CUDNN_VERSION=8.7.0, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=0 -fabi-version=11 -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-stringop-overflow -Wsuggest-override -Wno-psabi -Wno-error=pedantic -Wno-error=old-style-cast -Wno-missing-braces -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_VERSION=2.3.1, USE_CUDA=ON, USE_CUDNN=ON, USE_CUSPARSELT=1, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_GLOO=ON, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=1, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF, USE_ROCM_KERNEL_ASSERT=OFF,
#
# [08/30 09:44:37 detectron2]: Command line arguments: {'config_file': '/usr/local/lib/python3.10/dist-packages/magic_pdf/resources/model_config/layoutlmv3/layoutlmv3_base_inference.yaml', 'resume': False, 'eval_only': False, 'num_gpus': 1, 'num_machines': 1, 'machine_rank': 0, 'dist_url': 'tcp://127.0.0.1:57823', 'opts': ['MODEL.WEIGHTS', '/content/PDF-Extract-Kit/models/Layout/model_final.pth']}
# [08/30 09:44:37 detectron2]: Contents of args.config_file=/usr/local/lib/python3.10/dist-packages/magic_pdf/resources/model_config/layoutlmv3/layoutlmv3_base_inference.yaml:
# AUG:
#   DETR: true
# CACHE_DIR: ~/cache/huggingface
# CUDNN_BENCHMARK: false
# DATALOADER:
#   ASPECT_RATIO_GROUPING: true
#   FILTER_EMPTY_ANNOTATIONS: false
#   NUM_WORKERS: 4
#   REPEAT_THRESHOLD: 0.0
#   SAMPLER_TRAIN: TrainingSampler
# DATASETS:
#   PRECOMPUTED_PROPOSAL_TOPK_TEST: 1000
#   PRECOMPUTED_PROPOSAL_TOPK_TRAIN: 2000
#   PROPOSAL_FILES_TEST: []
#   PROPOSAL_FILES_TRAIN: []
#   TEST:
#   - scihub_train
#   TRAIN:
#   - scihub_train
# GLOBAL:
#   HACK: 1.0
# ICDAR_DATA_DIR_TEST: ''
# ICDAR_DATA_DIR_TRAIN: ''
# INPUT:
#   CROP:
#     ENABLED: true
#     SIZE:
#     - 384
#     - 600
#     TYPE: absolute_range
#   FORMAT: RGB
#   MASK_FORMAT: polygon
#   MAX_SIZE_TEST: 1333
#   MAX_SIZE_TRAIN: 1333
#   MIN_SIZE_TEST: 800
#   MIN_SIZE_TRAIN:
#   - 480
#   - 512
#   - 544
#   - 576
#   - 608
#   - 640
#   - 672
#   - 704
#   - 736
#   - 768
#   - 800
#   MIN_SIZE_TRAIN_SAMPLING: choice
#   RANDOM_FLIP: horizontal
# MODEL:
#   ANCHOR_GENERATOR:
#     ANGLES:
#     - - -90
#       - 0
#       - 90
#     ASPECT_RATIOS:
#     - - 0.5
#       - 1.0
#       - 2.0
#     NAME: DefaultAnchorGenerator
#     OFFSET: 0.0
#     SIZES:
#     - - 32
#     - - 64
#     - - 128
#     - - 256
#     - - 512
#   BACKBONE:
#     FREEZE_AT: 2
#     NAME: build_vit_fpn_backbone
#   CONFIG_PATH: ''
#   DEVICE: cuda
#   FPN:
#     FUSE_TYPE: sum
#     IN_FEATURES:
#     - layer3
#     - layer5
#     - layer7
#     - layer11
#     NORM: ''
#     OUT_CHANNELS: 256
#   IMAGE_ONLY: true
#   KEYPOINT_ON: false
#   LOAD_PROPOSALS: false
#   MASK_ON: true
#   META_ARCHITECTURE: VLGeneralizedRCNN
#   PANOPTIC_FPN:
#     COMBINE:
#       ENABLED: true
#       INSTANCES_CONFIDENCE_THRESH: 0.5
#       OVERLAP_THRESH: 0.5
#       STUFF_AREA_LIMIT: 4096
#     INSTANCE_LOSS_WEIGHT: 1.0
#   PIXEL_MEAN:
#   - 127.5
#   - 127.5
#   - 127.5
#   PIXEL_STD:
#   - 127.5
#   - 127.5
#   - 127.5
#   PROPOSAL_GENERATOR:
#     MIN_SIZE: 0
#     NAME: RPN
#   RESNETS:
#     DEFORM_MODULATED: false
#     DEFORM_NUM_GROUPS: 1
#     DEFORM_ON_PER_STAGE:
#     - false
#     - false
#     - false
#     - false
#     DEPTH: 50
#     NORM: FrozenBN
#     NUM_GROUPS: 1
#     OUT_FEATURES:
#     - res4
#     RES2_OUT_CHANNELS: 256
#     RES5_DILATION: 1
#     STEM_OUT_CHANNELS: 64
#     STRIDE_IN_1X1: true
#     WIDTH_PER_GROUP: 64
#   RETINANET:
#     BBOX_REG_LOSS_TYPE: smooth_l1
#     BBOX_REG_WEIGHTS:
#     - 1.0
#     - 1.0
#     - 1.0
#     - 1.0
#     FOCAL_LOSS_ALPHA: 0.25
#     FOCAL_LOSS_GAMMA: 2.0
#     IN_FEATURES:
#     - p3
#     - p4
#     - p5
#     - p6
#     - p7
#     IOU_LABELS:
#     - 0
#     - -1
#     - 1
#     IOU_THRESHOLDS:
#     - 0.4
#     - 0.5
#     NMS_THRESH_TEST: 0.5
#     NORM: ''
#     NUM_CLASSES: 10
#     NUM_CONVS: 4
#     PRIOR_PROB: 0.01
#     SCORE_THRESH_TEST: 0.05
#     SMOOTH_L1_LOSS_BETA: 0.1
#     TOPK_CANDIDATES_TEST: 1000
#   ROI_BOX_CASCADE_HEAD:
#     BBOX_REG_WEIGHTS:
#     - - 10.0
#       - 10.0
#       - 5.0
#       - 5.0
#     - - 20.0
#       - 20.0
#       - 10.0
#       - 10.0
#     - - 30.0
#       - 30.0
#       - 15.0
#       - 15.0
#     IOUS:
#     - 0.5
#     - 0.6
#     - 0.7
#   ROI_BOX_HEAD:
#     BBOX_REG_LOSS_TYPE: smooth_l1
#     BBOX_REG_LOSS_WEIGHT: 1.0
#     BBOX_REG_WEIGHTS:
#     - 10.0
#     - 10.0
#     - 5.0
#     - 5.0
#     CLS_AGNOSTIC_BBOX_REG: true
#     CONV_DIM: 256
#     FC_DIM: 1024
#     NAME: FastRCNNConvFCHead
#     NORM: ''
#     NUM_CONV: 0
#     NUM_FC: 2
#     POOLER_RESOLUTION: 7
#     POOLER_SAMPLING_RATIO: 0
#     POOLER_TYPE: ROIAlignV2
#     SMOOTH_L1_BETA: 0.0
#     TRAIN_ON_PRED_BOXES: false
#   ROI_HEADS:
#     BATCH_SIZE_PER_IMAGE: 512
#     IN_FEATURES:
#     - p2
#     - p3
#     - p4
#     - p5
#     IOU_LABELS:
#     - 0
#     - 1
#     IOU_THRESHOLDS:
#     - 0.5
#     NAME: CascadeROIHeads
#     NMS_THRESH_TEST: 0.5
#     NUM_CLASSES: 10
#     POSITIVE_FRACTION: 0.25
#     PROPOSAL_APPEND_GT: true
#     SCORE_THRESH_TEST: 0.05
#   ROI_KEYPOINT_HEAD:
#     CONV_DIMS:
#     - 512
#     - 512
#     - 512
#     - 512
#     - 512
#     - 512
#     - 512
#     - 512
#     LOSS_WEIGHT: 1.0
#     MIN_KEYPOINTS_PER_IMAGE: 1
#     NAME: KRCNNConvDeconvUpsampleHead
#     NORMALIZE_LOSS_BY_VISIBLE_KEYPOINTS: true
#     NUM_KEYPOINTS: 17
#     POOLER_RESOLUTION: 14
#     POOLER_SAMPLING_RATIO: 0
#     POOLER_TYPE: ROIAlignV2
#   ROI_MASK_HEAD:
#     CLS_AGNOSTIC_MASK: false
#     CONV_DIM: 256
#     NAME: MaskRCNNConvUpsampleHead
#     NORM: ''
#     NUM_CONV: 4
#     POOLER_RESOLUTION: 14
#     POOLER_SAMPLING_RATIO: 0
#     POOLER_TYPE: ROIAlignV2
#   RPN:
#     BATCH_SIZE_PER_IMAGE: 256
#     BBOX_REG_LOSS_TYPE: smooth_l1
#     BBOX_REG_LOSS_WEIGHT: 1.0
#     BBOX_REG_WEIGHTS:
#     - 1.0
#     - 1.0
#     - 1.0
#     - 1.0
#     BOUNDARY_THRESH: -1
#     CONV_DIMS:
#     - -1
#     HEAD_NAME: StandardRPNHead
#     IN_FEATURES:
#     - p2
#     - p3
#     - p4
#     - p5
#     - p6
#     IOU_LABELS:
#     - 0
#     - -1
#     - 1
#     IOU_THRESHOLDS:
#     - 0.3
#     - 0.7
#     LOSS_WEIGHT: 1.0
#     NMS_THRESH: 0.7
#     POSITIVE_FRACTION: 0.5
#     POST_NMS_TOPK_TEST: 1000
#     POST_NMS_TOPK_TRAIN: 2000
#     PRE_NMS_TOPK_TEST: 1000
#     PRE_NMS_TOPK_TRAIN: 2000
#     SMOOTH_L1_BETA: 0.0
#   SEM_SEG_HEAD:
#     COMMON_STRIDE: 4
#     CONVS_DIM: 128
#     IGNORE_VALUE: 255
#     IN_FEATURES:
#     - p2
#     - p3
#     - p4
#     - p5
#     LOSS_WEIGHT: 1.0
#     NAME: SemSegFPNHead
#     NORM: GN
#     NUM_CLASSES: 10
#   VIT:
#     DROP_PATH: 0.1
#     IMG_SIZE:
#     - 224
#     - 224
#     NAME: layoutlmv3_base
#     OUT_FEATURES:
#     - layer3
#     - layer5
#     - layer7
#     - layer11
#     POS_TYPE: abs
#   WEIGHTS:
# OUTPUT_DIR:
# SCIHUB_DATA_DIR_TRAIN: ~/publaynet/layout_scihub/train
# SEED: 42
# SOLVER:
#   AMP:
#     ENABLED: true
#   BACKBONE_MULTIPLIER: 1.0
#   BASE_LR: 0.0002
#   BIAS_LR_FACTOR: 1.0
#   CHECKPOINT_PERIOD: 2000
#   CLIP_GRADIENTS:
#     CLIP_TYPE: full_model
#     CLIP_VALUE: 1.0
#     ENABLED: true
#     NORM_TYPE: 2.0
#   GAMMA: 0.1
#   GRADIENT_ACCUMULATION_STEPS: 1
#   IMS_PER_BATCH: 32
#   LR_SCHEDULER_NAME: WarmupCosineLR
#   MAX_ITER: 20000
#   MOMENTUM: 0.9
#   NESTEROV: false
#   OPTIMIZER: ADAMW
#   REFERENCE_WORLD_SIZE: 0
#   STEPS:
#   - 10000
#   WARMUP_FACTOR: 0.01
#   WARMUP_ITERS: 333
#   WARMUP_METHOD: linear
#   WEIGHT_DECAY: 0.05
#   WEIGHT_DECAY_BIAS: null
#   WEIGHT_DECAY_NORM: 0.0
# TEST:
#   AUG:
#     ENABLED: false
#     FLIP: true
#     MAX_SIZE: 4000
#     MIN_SIZES:
#     - 400
#     - 500
#     - 600
#     - 700
#     - 800
#     - 900
#     - 1000
#     - 1100
#     - 1200
#   DETECTIONS_PER_IMAGE: 100
#   EVAL_PERIOD: 1000
#   EXPECTED_RESULTS: []
#   KEYPOINT_OKS_SIGMAS: []
#   PRECISE_BN:
#     ENABLED: false
#     NUM_ITER: 200
# VERSION: 2
# VIS_PERIOD: 0
#
# [08/30 09:44:39 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from /content/PDF-Extract-Kit/models/Layout/model_final.pth ...
# [08/30 09:44:39 fvcore.common.checkpoint]: [Checkpointer] Loading from /content/PDF-Extract-Kit/models/Layout/model_final.pth ...
# 2024-08-30 09:44:42.613 | INFO     | magic_pdf.model.pdf_extract_kit:__init__:148 - DocAnalysis init done!
# 2024-08-30 09:44:42.614 | INFO     | magic_pdf.model.doc_analyze_by_custom_model:custom_model_init:98 - model init cost: 59.48518204689026
# 2024-08-30 09:44:45.331 | INFO     | magic_pdf.model.pdf_extract_kit:__call__:159 - layout detection cost: 2.68
#
# 0: 1888x1472 11 embeddings, 237.2ms
# Speed: 52.3ms preprocess, 237.2ms inference, 2.5ms postprocess per image at shape (1, 3, 1888, 1472)
# 2024-08-30 09:44:47.340 | INFO     | magic_pdf.model.pdf_extract_kit:__call__:189 - formula nums: 11, mfr time: 0.76
# 2024-08-30 09:44:47.346 | INFO     | magic_pdf.model.doc_analyze_by_custom_model:doc_analyze:124 - doc analyze cost: 4.6917054653167725
# 2024-08-30 09:44:47.366 | INFO     | magic_pdf.pdf_parse_union_core:pdf_parse_union:221 - page_id: 0, last_page_cost_time: 0.0
# 2024-08-30 09:44:47.657 | INFO     | magic_pdf.pipe.UNIPipe:pipe_mk_markdown:48 - uni_pipe mk mm_markdown finished
# 2024-08-30 09:44:47.677 | INFO     | magic_pdf.pipe.UNIPipe:pipe_mk_uni_format:43 - uni_pipe mk content list finished
# 2024-08-30 09:44:47.677 | INFO     | magic_pdf.tools.common:do_parse:119 - local output dir is output/demo/auto
# 2024-08-30 09:44:55.734 | INFO     | magic_pdf.libs.pdf_check:detect_invalid_chars:57 - cid_count: 14, text_len: 26394, cid_chars_radio: 0.0005324003650745361
# 2024-08-30 09:45:09.844 | INFO     | magic_pdf.model.pdf_extract_kit:__init__:111 - DocAnalysis init, this may take some times. apply_layout: True, apply_formula: True, apply_ocr: False, apply_table: False
# 2024-08-30 09:45:09.844 | INFO     | magic_pdf.model.pdf_extract_kit:__init__:119 - using device: cuda
# 2024-08-30 09:45:09.844 | INFO     | magic_pdf.model.pdf_extract_kit:__init__:121 - using models_dir: /content/PDF-Extract-Kit/models
# CustomVisionEncoderDecoderModel init
# CustomMBartForCausalLM init
# CustomMBartDecoder init
# [08/30 09:45:48 detectron2]: Rank of current process: 0. World size: 1
# [08/30 09:45:49 detectron2]: Environment info:
# -------------------------------  -----------------------------------------------------------------
# sys.platform                     linux
# Python                           3.10.12 (main, Jul 29 2024, 16:56:48) [GCC 11.4.0]
# numpy                            1.26.3
# detectron2                       0.6 @/usr/local/lib/python3.10/dist-packages/detectron2
# Compiler                         GCC 11.4
# CUDA compiler                    not available
# DETECTRON2_ENV_MODULE            <not set>
# PyTorch                          2.3.1+cu118 @/usr/local/lib/python3.10/dist-packages/torch
# PyTorch debug build              False
# torch._C._GLIBCXX_USE_CXX11_ABI  False
# GPU available                    Yes
# GPU 0                            Tesla T4 (arch=7.5)
# Driver version                   535.104.05
# CUDA_HOME                        /usr/local/cuda
# Pillow                           10.2.0
# torchvision                      0.18.1+cu118 @/usr/local/lib/python3.10/dist-packages/torchvision
# torchvision arch flags           3.5, 5.0, 6.0, 7.0, 7.5, 8.0, 8.6
# fvcore                           0.1.5.post20221221
# iopath                           0.1.9
# cv2                              4.6.0
# -------------------------------  -----------------------------------------------------------------
# PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v3.3.6 (Git Hash 86e6af5974177e513fd3fee58425e1063e7f1361)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX512
#   - CUDA Runtime 11.8
#   - NVCC architecture flags: -gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_90,code=sm_90
#   - CuDNN 8.7
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.8, CUDNN_VERSION=8.7.0, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=0 -fabi-version=11 -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-stringop-overflow -Wsuggest-override -Wno-psabi -Wno-error=pedantic -Wno-error=old-style-cast -Wno-missing-braces -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_VERSION=2.3.1, USE_CUDA=ON, USE_CUDNN=ON, USE_CUSPARSELT=1, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_GLOO=ON, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=1, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF, USE_ROCM_KERNEL_ASSERT=OFF,
#
# [08/30 09:45:49 detectron2]: Command line arguments: {'config_file': '/usr/local/lib/python3.10/dist-packages/magic_pdf/resources/model_config/layoutlmv3/layoutlmv3_base_inference.yaml', 'resume': False, 'eval_only': False, 'num_gpus': 1, 'num_machines': 1, 'machine_rank': 0, 'dist_url': 'tcp://127.0.0.1:57823', 'opts': ['MODEL.WEIGHTS', '/content/PDF-Extract-Kit/models/Layout/model_final.pth']}
# [08/30 09:45:49 detectron2]: Contents of args.config_file=/usr/local/lib/python3.10/dist-packages/magic_pdf/resources/model_config/layoutlmv3/layoutlmv3_base_inference.yaml:
# AUG:
#   DETR: true
# CACHE_DIR: ~/cache/huggingface
# CUDNN_BENCHMARK: false
# DATALOADER:
#   ASPECT_RATIO_GROUPING: true
#   FILTER_EMPTY_ANNOTATIONS: false
#   NUM_WORKERS: 4
#   REPEAT_THRESHOLD: 0.0
#   SAMPLER_TRAIN: TrainingSampler
# DATASETS:
#   PRECOMPUTED_PROPOSAL_TOPK_TEST: 1000
#   PRECOMPUTED_PROPOSAL_TOPK_TRAIN: 2000
#   PROPOSAL_FILES_TEST: []
#   PROPOSAL_FILES_TRAIN: []
#   TEST:
#   - scihub_train
#   TRAIN:
#   - scihub_train
# GLOBAL:
#   HACK: 1.0
# ICDAR_DATA_DIR_TEST: ''
# ICDAR_DATA_DIR_TRAIN: ''
# INPUT:
#   CROP:
#     ENABLED: true
#     SIZE:
#     - 384
#     - 600
#     TYPE: absolute_range
#   FORMAT: RGB
#   MASK_FORMAT: polygon
#   MAX_SIZE_TEST: 1333
#   MAX_SIZE_TRAIN: 1333
#   MIN_SIZE_TEST: 800
#   MIN_SIZE_TRAIN:
#   - 480
#   - 512
#   - 544
#   - 576
#   - 608
#   - 640
#   - 672
#   - 704
#   - 736
#   - 768
#   - 800
#   MIN_SIZE_TRAIN_SAMPLING: choice
#   RANDOM_FLIP: horizontal
# MODEL:
#   ANCHOR_GENERATOR:
#     ANGLES:
#     - - -90
#       - 0
#       - 90
#     ASPECT_RATIOS:
#     - - 0.5
#       - 1.0
#       - 2.0
#     NAME: DefaultAnchorGenerator
#     OFFSET: 0.0
#     SIZES:
#     - - 32
#     - - 64
#     - - 128
#     - - 256
#     - - 512
#   BACKBONE:
#     FREEZE_AT: 2
#     NAME: build_vit_fpn_backbone
#   CONFIG_PATH: ''
#   DEVICE: cuda
#   FPN:
#     FUSE_TYPE: sum
#     IN_FEATURES:
#     - layer3
#     - layer5
#     - layer7
#     - layer11
#     NORM: ''
#     OUT_CHANNELS: 256
#   IMAGE_ONLY: true
#   KEYPOINT_ON: false
#   LOAD_PROPOSALS: false
#   MASK_ON: true
#   META_ARCHITECTURE: VLGeneralizedRCNN
#   PANOPTIC_FPN:
#     COMBINE:
#       ENABLED: true
#       INSTANCES_CONFIDENCE_THRESH: 0.5
#       OVERLAP_THRESH: 0.5
#       STUFF_AREA_LIMIT: 4096
#     INSTANCE_LOSS_WEIGHT: 1.0
#   PIXEL_MEAN:
#   - 127.5
#   - 127.5
#   - 127.5
#   PIXEL_STD:
#   - 127.5
#   - 127.5
#   - 127.5
#   PROPOSAL_GENERATOR:
#     MIN_SIZE: 0
#     NAME: RPN
#   RESNETS:
#     DEFORM_MODULATED: false
#     DEFORM_NUM_GROUPS: 1
#     DEFORM_ON_PER_STAGE:
#     - false
#     - false
#     - false
#     - false
#     DEPTH: 50
#     NORM: FrozenBN
#     NUM_GROUPS: 1
#     OUT_FEATURES:
#     - res4
#     RES2_OUT_CHANNELS: 256
#     RES5_DILATION: 1
#     STEM_OUT_CHANNELS: 64
#     STRIDE_IN_1X1: true
#     WIDTH_PER_GROUP: 64
#   RETINANET:
#     BBOX_REG_LOSS_TYPE: smooth_l1
#     BBOX_REG_WEIGHTS:
#     - 1.0
#     - 1.0
#     - 1.0
#     - 1.0
#     FOCAL_LOSS_ALPHA: 0.25
#     FOCAL_LOSS_GAMMA: 2.0
#     IN_FEATURES:
#     - p3
#     - p4
#     - p5
#     - p6
#     - p7
#     IOU_LABELS:
#     - 0
#     - -1
#     - 1
#     IOU_THRESHOLDS:
#     - 0.4
#     - 0.5
#     NMS_THRESH_TEST: 0.5
#     NORM: ''
#     NUM_CLASSES: 10
#     NUM_CONVS: 4
#     PRIOR_PROB: 0.01
#     SCORE_THRESH_TEST: 0.05
#     SMOOTH_L1_LOSS_BETA: 0.1
#     TOPK_CANDIDATES_TEST: 1000
#   ROI_BOX_CASCADE_HEAD:
#     BBOX_REG_WEIGHTS:
#     - - 10.0
#       - 10.0
#       - 5.0
#       - 5.0
#     - - 20.0
#       - 20.0
#       - 10.0
#       - 10.0
#     - - 30.0
#       - 30.0
#       - 15.0
#       - 15.0
#     IOUS:
#     - 0.5
#     - 0.6
#     - 0.7
#   ROI_BOX_HEAD:
#     BBOX_REG_LOSS_TYPE: smooth_l1
#     BBOX_REG_LOSS_WEIGHT: 1.0
#     BBOX_REG_WEIGHTS:
#     - 10.0
#     - 10.0
#     - 5.0
#     - 5.0
#     CLS_AGNOSTIC_BBOX_REG: true
#     CONV_DIM: 256
#     FC_DIM: 1024
#     NAME: FastRCNNConvFCHead
#     NORM: ''
#     NUM_CONV: 0
#     NUM_FC: 2
#     POOLER_RESOLUTION: 7
#     POOLER_SAMPLING_RATIO: 0
#     POOLER_TYPE: ROIAlignV2
#     SMOOTH_L1_BETA: 0.0
#     TRAIN_ON_PRED_BOXES: false
#   ROI_HEADS:
#     BATCH_SIZE_PER_IMAGE: 512
#     IN_FEATURES:
#     - p2
#     - p3
#     - p4
#     - p5
#     IOU_LABELS:
#     - 0
#     - 1
#     IOU_THRESHOLDS:
#     - 0.5
#     NAME: CascadeROIHeads
#     NMS_THRESH_TEST: 0.5
#     NUM_CLASSES: 10
#     POSITIVE_FRACTION: 0.25
#     PROPOSAL_APPEND_GT: true
#     SCORE_THRESH_TEST: 0.05
#   ROI_KEYPOINT_HEAD:
#     CONV_DIMS:
#     - 512
#     - 512
#     - 512
#     - 512
#     - 512
#     - 512
#     - 512
#     - 512
#     LOSS_WEIGHT: 1.0
#     MIN_KEYPOINTS_PER_IMAGE: 1
#     NAME: KRCNNConvDeconvUpsampleHead
#     NORMALIZE_LOSS_BY_VISIBLE_KEYPOINTS: true
#     NUM_KEYPOINTS: 17
#     POOLER_RESOLUTION: 14
#     POOLER_SAMPLING_RATIO: 0
#     POOLER_TYPE: ROIAlignV2
#   ROI_MASK_HEAD:
#     CLS_AGNOSTIC_MASK: false
#     CONV_DIM: 256
#     NAME: MaskRCNNConvUpsampleHead
#     NORM: ''
#     NUM_CONV: 4
#     POOLER_RESOLUTION: 14
#     POOLER_SAMPLING_RATIO: 0
#     POOLER_TYPE: ROIAlignV2
#   RPN:
#     BATCH_SIZE_PER_IMAGE: 256
#     BBOX_REG_LOSS_TYPE: smooth_l1
#     BBOX_REG_LOSS_WEIGHT: 1.0
#     BBOX_REG_WEIGHTS:
#     - 1.0
#     - 1.0
#     - 1.0
#     - 1.0
#     BOUNDARY_THRESH: -1
#     CONV_DIMS:
#     - -1
#     HEAD_NAME: StandardRPNHead
#     IN_FEATURES:
#     - p2
#     - p3
#     - p4
#     - p5
#     - p6
#     IOU_LABELS:
#     - 0
#     - -1
#     - 1
#     IOU_THRESHOLDS:
#     - 0.3
#     - 0.7
#     LOSS_WEIGHT: 1.0
#     NMS_THRESH: 0.7
#     POSITIVE_FRACTION: 0.5
#     POST_NMS_TOPK_TEST: 1000
#     POST_NMS_TOPK_TRAIN: 2000
#     PRE_NMS_TOPK_TEST: 1000
#     PRE_NMS_TOPK_TRAIN: 2000
#     SMOOTH_L1_BETA: 0.0
#   SEM_SEG_HEAD:
#     COMMON_STRIDE: 4
#     CONVS_DIM: 128
#     IGNORE_VALUE: 255
#     IN_FEATURES:
#     - p2
#     - p3
#     - p4
#     - p5
#     LOSS_WEIGHT: 1.0
#     NAME: SemSegFPNHead
#     NORM: GN
#     NUM_CLASSES: 10
#   VIT:
#     DROP_PATH: 0.1
#     IMG_SIZE:
#     - 224
#     - 224
#     NAME: layoutlmv3_base
#     OUT_FEATURES:
#     - layer3
#     - layer5
#     - layer7
#     - layer11
#     POS_TYPE: abs
#   WEIGHTS:
# OUTPUT_DIR:
# SCIHUB_DATA_DIR_TRAIN: ~/publaynet/layout_scihub/train
# SEED: 42
# SOLVER:
#   AMP:
#     ENABLED: true
#   BACKBONE_MULTIPLIER: 1.0
#   BASE_LR: 0.0002
#   BIAS_LR_FACTOR: 1.0
#   CHECKPOINT_PERIOD: 2000
#   CLIP_GRADIENTS:
#     CLIP_TYPE: full_model
#     CLIP_VALUE: 1.0
#     ENABLED: true
#     NORM_TYPE: 2.0
#   GAMMA: 0.1
#   GRADIENT_ACCUMULATION_STEPS: 1
#   IMS_PER_BATCH: 32
#   LR_SCHEDULER_NAME: WarmupCosineLR
#   MAX_ITER: 20000
#   MOMENTUM: 0.9
#   NESTEROV: false
#   OPTIMIZER: ADAMW
#   REFERENCE_WORLD_SIZE: 0
#   STEPS:
#   - 10000
#   WARMUP_FACTOR: 0.01
#   WARMUP_ITERS: 333
#   WARMUP_METHOD: linear
#   WEIGHT_DECAY: 0.05
#   WEIGHT_DECAY_BIAS: null
#   WEIGHT_DECAY_NORM: 0.0
# TEST:
#   AUG:
#     ENABLED: false
#     FLIP: true
#     MAX_SIZE: 4000
#     MIN_SIZES:
#     - 400
#     - 500
#     - 600
#     - 700
#     - 800
#     - 900
#     - 1000
#     - 1100
#     - 1200
#   DETECTIONS_PER_IMAGE: 100
#   EVAL_PERIOD: 1000
#   EXPECTED_RESULTS: []
#   KEYPOINT_OKS_SIGMAS: []
#   PRECISE_BN:
#     ENABLED: false
#     NUM_ITER: 200
# VERSION: 2
# VIS_PERIOD: 0
#
# [08/30 09:45:51 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from /content/PDF-Extract-Kit/models/Layout/model_final.pth ...
# [08/30 09:45:51 fvcore.common.checkpoint]: [Checkpointer] Loading from /content/PDF-Extract-Kit/models/Layout/model_final.pth ...
# 2024-08-30 09:45:54.281 | INFO     | magic_pdf.model.pdf_extract_kit:__init__:148 - DocAnalysis init done!
# 2024-08-30 09:45:54.282 | INFO     | magic_pdf.model.doc_analyze_by_custom_model:custom_model_init:98 - model init cost: 58.546337366104126
# 2024-08-30 09:45:57.367 | INFO     | magic_pdf.model.pdf_extract_kit:__call__:159 - layout detection cost: 2.83
#
# 0: 1888x1472 2 embeddings, 237.3ms
# Speed: 51.0ms preprocess, 237.3ms inference, 2.1ms postprocess per image at shape (1, 3, 1888, 1472)
# 2024-08-30 09:45:59.440 | INFO     | magic_pdf.model.pdf_extract_kit:__call__:189 - formula nums: 2, mfr time: 0.62
# 2024-08-30 09:46:00.293 | INFO     | magic_pdf.model.pdf_extract_kit:__call__:159 - layout detection cost: 0.85
#
# 0: 1888x1472 24 embeddings, 3 isolateds, 235.3ms
# Speed: 17.3ms preprocess, 235.3ms inference, 1.8ms postprocess per image at shape (1, 3, 1888, 1472)
# 2024-08-30 09:46:05.029 | INFO     | magic_pdf.model.pdf_extract_kit:__call__:189 - formula nums: 27, mfr time: 4.38
# 2024-08-30 09:46:05.940 | INFO     | magic_pdf.model.pdf_extract_kit:__call__:159 - layout detection cost: 0.91
#
# 0: 1888x1472 28 embeddings, 6 isolateds, 236.6ms
# Speed: 16.1ms preprocess, 236.6ms inference, 2.2ms postprocess per image at shape (1, 3, 1888, 1472)
# 2024-08-30 09:46:14.200 | INFO     | magic_pdf.model.pdf_extract_kit:__call__:189 - formula nums: 34, mfr time: 7.89
# 2024-08-30 09:46:15.056 | INFO     | magic_pdf.model.pdf_extract_kit:__call__:159 - layout detection cost: 0.85
#
# 0: 1888x1472 26 embeddings, 236.8ms
# Speed: 16.0ms preprocess, 236.8ms inference, 1.6ms postprocess per image at shape (1, 3, 1888, 1472)
# 2024-08-30 09:46:16.240 | INFO     | magic_pdf.model.pdf_extract_kit:__call__:189 - formula nums: 26, mfr time: 0.85
# 2024-08-30 09:46:17.064 | INFO     | magic_pdf.model.pdf_extract_kit:__call__:159 - layout detection cost: 0.82
#
# 0: 1888x1472 8 embeddings, 240.4ms
# Speed: 16.8ms preprocess, 240.4ms inference, 1.7ms postprocess per image at shape (1, 3, 1888, 1472)
# 2024-08-30 09:46:17.740 | INFO     | magic_pdf.model.pdf_extract_kit:__call__:189 - formula nums: 8, mfr time: 0.39
# 2024-08-30 09:46:18.526 | INFO     | magic_pdf.model.pdf_extract_kit:__call__:159 - layout detection cost: 0.78
#
# 0: 1888x1472 (no detections), 246.8ms
# Speed: 16.6ms preprocess, 246.8ms inference, 0.9ms postprocess per image at shape (1, 3, 1888, 1472)
# 2024-08-30 09:46:18.791 | INFO     | magic_pdf.model.pdf_extract_kit:__call__:189 - formula nums: 0, mfr time: 0.0
# 2024-08-30 09:46:18.797 | INFO     | magic_pdf.model.doc_analyze_by_custom_model:doc_analyze:124 - doc analyze cost: 24.260830879211426
# 2024-08-30 09:46:18.909 | INFO     | magic_pdf.pdf_parse_union_core:pdf_parse_union:221 - page_id: 0, last_page_cost_time: 0.0
# 2024-08-30 09:46:18.992 | INFO     | magic_pdf.pdf_parse_union_core:pdf_parse_union:221 - page_id: 1, last_page_cost_time: 0.08
# 2024-08-30 09:46:19.101 | INFO     | magic_pdf.pdf_parse_union_core:pdf_parse_union:221 - page_id: 2, last_page_cost_time: 0.11
# 2024-08-30 09:46:19.253 | INFO     | magic_pdf.pdf_parse_union_core:pdf_parse_union:221 - page_id: 3, last_page_cost_time: 0.15
# 2024-08-30 09:46:19.587 | INFO     | magic_pdf.pdf_parse_union_core:pdf_parse_union:221 - page_id: 4, last_page_cost_time: 0.33
# 2024-08-30 09:46:19.778 | INFO     | magic_pdf.pdf_parse_union_core:pdf_parse_union:221 - page_id: 5, last_page_cost_time: 0.19
# 2024-08-30 09:46:19.933 | INFO     | magic_pdf.para.para_split_v2:__detect_list_lines:140 - 发现了列表，列表行数：[(24, 43)]， [[24, 27, 30, 34, 39]]
# 2024-08-30 09:46:19.934 | INFO     | magic_pdf.para.para_split_v2:__detect_list_lines:153 - 列表行的第24到第43行是列表
# 2024-08-30 09:46:19.938 | INFO     | magic_pdf.para.para_split_v2:__detect_list_lines:140 - 发现了列表，列表行数：[(0, 59)]， [[0, 4, 8, 12, 16, 21, 24, 27, 30, 34, 38, 42, 46, 49, 54, 57]]
# 2024-08-30 09:46:19.938 | INFO     | magic_pdf.para.para_split_v2:__detect_list_lines:153 - 列表行的第0到第59行是列表
# 2024-08-30 09:46:19.938 | INFO     | magic_pdf.para.para_split_v2:para_split:764 - 连接了第0页和第1页的段落
# 2024-08-30 09:46:19.939 | INFO     | magic_pdf.para.para_split_v2:para_split:764 - 连接了第1页和第2页的段落
# 2024-08-30 09:46:19.939 | INFO     | magic_pdf.para.para_split_v2:para_split:764 - 连接了第2页和第3页的段落
# 2024-08-30 09:46:19.939 | INFO     | magic_pdf.para.para_split_v2:para_split:764 - 连接了第3页和第4页的段落
# 2024-08-30 09:46:20.866 | INFO     | magic_pdf.pipe.UNIPipe:pipe_mk_markdown:48 - uni_pipe mk mm_markdown finished
# 2024-08-30 09:46:20.979 | INFO     | magic_pdf.pipe.UNIPipe:pipe_mk_uni_format:43 - uni_pipe mk content list finished
# 2024-08-30 09:46:20.979 | INFO     | magic_pdf.tools.common:do_parse:119 - local output dir is output/demo2/auto
# 2024-08-30 09:46:29.006 | INFO     | magic_pdf.libs.pdf_check:detect_invalid_chars:57 - cid_count: 9, text_len: 33569, cid_chars_radio: 0.00026853647620468446
# 2024-08-30 09:46:43.198 | INFO     | magic_pdf.model.pdf_extract_kit:__init__:111 - DocAnalysis init, this may take some times. apply_layout: True, apply_formula: True, apply_ocr: False, apply_table: False
# 2024-08-30 09:46:43.198 | INFO     | magic_pdf.model.pdf_extract_kit:__init__:119 - using device: cuda
# 2024-08-30 09:46:43.198 | INFO     | magic_pdf.model.pdf_extract_kit:__init__:121 - using models_dir: /content/PDF-Extract-Kit/models
# CustomVisionEncoderDecoderModel init
# CustomMBartForCausalLM init
# CustomMBartDecoder init
# [08/30 09:47:21 detectron2]: Rank of current process: 0. World size: 1
# [08/30 09:47:22 detectron2]: Environment info:
# -------------------------------  -----------------------------------------------------------------
# sys.platform                     linux
# Python                           3.10.12 (main, Jul 29 2024, 16:56:48) [GCC 11.4.0]
# numpy                            1.26.3
# detectron2                       0.6 @/usr/local/lib/python3.10/dist-packages/detectron2
# Compiler                         GCC 11.4
# CUDA compiler                    not available
# DETECTRON2_ENV_MODULE            <not set>
# PyTorch                          2.3.1+cu118 @/usr/local/lib/python3.10/dist-packages/torch
# PyTorch debug build              False
# torch._C._GLIBCXX_USE_CXX11_ABI  False
# GPU available                    Yes
# GPU 0                            Tesla T4 (arch=7.5)
# Driver version                   535.104.05
# CUDA_HOME                        /usr/local/cuda
# Pillow                           10.2.0
# torchvision                      0.18.1+cu118 @/usr/local/lib/python3.10/dist-packages/torchvision
# torchvision arch flags           3.5, 5.0, 6.0, 7.0, 7.5, 8.0, 8.6
# fvcore                           0.1.5.post20221221
# iopath                           0.1.9
# cv2                              4.6.0
# -------------------------------  -----------------------------------------------------------------
# PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v3.3.6 (Git Hash 86e6af5974177e513fd3fee58425e1063e7f1361)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX512
#   - CUDA Runtime 11.8
#   - NVCC architecture flags: -gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_90,code=sm_90
#   - CuDNN 8.7
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.8, CUDNN_VERSION=8.7.0, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=0 -fabi-version=11 -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-stringop-overflow -Wsuggest-override -Wno-psabi -Wno-error=pedantic -Wno-error=old-style-cast -Wno-missing-braces -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_VERSION=2.3.1, USE_CUDA=ON, USE_CUDNN=ON, USE_CUSPARSELT=1, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_GLOO=ON, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=1, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF, USE_ROCM_KERNEL_ASSERT=OFF,
#
# [08/30 09:47:22 detectron2]: Command line arguments: {'config_file': '/usr/local/lib/python3.10/dist-packages/magic_pdf/resources/model_config/layoutlmv3/layoutlmv3_base_inference.yaml', 'resume': False, 'eval_only': False, 'num_gpus': 1, 'num_machines': 1, 'machine_rank': 0, 'dist_url': 'tcp://127.0.0.1:57823', 'opts': ['MODEL.WEIGHTS', '/content/PDF-Extract-Kit/models/Layout/model_final.pth']}
# [08/30 09:47:22 detectron2]: Contents of args.config_file=/usr/local/lib/python3.10/dist-packages/magic_pdf/resources/model_config/layoutlmv3/layoutlmv3_base_inference.yaml:
# AUG:
#   DETR: true
# CACHE_DIR: ~/cache/huggingface
# CUDNN_BENCHMARK: false
# DATALOADER:
#   ASPECT_RATIO_GROUPING: true
#   FILTER_EMPTY_ANNOTATIONS: false
#   NUM_WORKERS: 4
#   REPEAT_THRESHOLD: 0.0
#   SAMPLER_TRAIN: TrainingSampler
# DATASETS:
#   PRECOMPUTED_PROPOSAL_TOPK_TEST: 1000
#   PRECOMPUTED_PROPOSAL_TOPK_TRAIN: 2000
#   PROPOSAL_FILES_TEST: []
#   PROPOSAL_FILES_TRAIN: []
#   TEST:
#   - scihub_train
#   TRAIN:
#   - scihub_train
# GLOBAL:
#   HACK: 1.0
# ICDAR_DATA_DIR_TEST: ''
# ICDAR_DATA_DIR_TRAIN: ''
# INPUT:
#   CROP:
#     ENABLED: true
#     SIZE:
#     - 384
#     - 600
#     TYPE: absolute_range
#   FORMAT: RGB
#   MASK_FORMAT: polygon
#   MAX_SIZE_TEST: 1333
#   MAX_SIZE_TRAIN: 1333
#   MIN_SIZE_TEST: 800
#   MIN_SIZE_TRAIN:
#   - 480
#   - 512
#   - 544
#   - 576
#   - 608
#   - 640
#   - 672
#   - 704
#   - 736
#   - 768
#   - 800
#   MIN_SIZE_TRAIN_SAMPLING: choice
#   RANDOM_FLIP: horizontal
# MODEL:
#   ANCHOR_GENERATOR:
#     ANGLES:
#     - - -90
#       - 0
#       - 90
#     ASPECT_RATIOS:
#     - - 0.5
#       - 1.0
#       - 2.0
#     NAME: DefaultAnchorGenerator
#     OFFSET: 0.0
#     SIZES:
#     - - 32
#     - - 64
#     - - 128
#     - - 256
#     - - 512
#   BACKBONE:
#     FREEZE_AT: 2
#     NAME: build_vit_fpn_backbone
#   CONFIG_PATH: ''
#   DEVICE: cuda
#   FPN:
#     FUSE_TYPE: sum
#     IN_FEATURES:
#     - layer3
#     - layer5
#     - layer7
#     - layer11
#     NORM: ''
#     OUT_CHANNELS: 256
#   IMAGE_ONLY: true
#   KEYPOINT_ON: false
#   LOAD_PROPOSALS: false
#   MASK_ON: true
#   META_ARCHITECTURE: VLGeneralizedRCNN
#   PANOPTIC_FPN:
#     COMBINE:
#       ENABLED: true
#       INSTANCES_CONFIDENCE_THRESH: 0.5
#       OVERLAP_THRESH: 0.5
#       STUFF_AREA_LIMIT: 4096
#     INSTANCE_LOSS_WEIGHT: 1.0
#   PIXEL_MEAN:
#   - 127.5
#   - 127.5
#   - 127.5
#   PIXEL_STD:
#   - 127.5
#   - 127.5
#   - 127.5
#   PROPOSAL_GENERATOR:
#     MIN_SIZE: 0
#     NAME: RPN
#   RESNETS:
#     DEFORM_MODULATED: false
#     DEFORM_NUM_GROUPS: 1
#     DEFORM_ON_PER_STAGE:
#     - false
#     - false
#     - false
#     - false
#     DEPTH: 50
#     NORM: FrozenBN
#     NUM_GROUPS: 1
#     OUT_FEATURES:
#     - res4
#     RES2_OUT_CHANNELS: 256
#     RES5_DILATION: 1
#     STEM_OUT_CHANNELS: 64
#     STRIDE_IN_1X1: true
#     WIDTH_PER_GROUP: 64
#   RETINANET:
#     BBOX_REG_LOSS_TYPE: smooth_l1
#     BBOX_REG_WEIGHTS:
#     - 1.0
#     - 1.0
#     - 1.0
#     - 1.0
#     FOCAL_LOSS_ALPHA: 0.25
#     FOCAL_LOSS_GAMMA: 2.0
#     IN_FEATURES:
#     - p3
#     - p4
#     - p5
#     - p6
#     - p7
#     IOU_LABELS:
#     - 0
#     - -1
#     - 1
#     IOU_THRESHOLDS:
#     - 0.4
#     - 0.5
#     NMS_THRESH_TEST: 0.5
#     NORM: ''
#     NUM_CLASSES: 10
#     NUM_CONVS: 4
#     PRIOR_PROB: 0.01
#     SCORE_THRESH_TEST: 0.05
#     SMOOTH_L1_LOSS_BETA: 0.1
#     TOPK_CANDIDATES_TEST: 1000
#   ROI_BOX_CASCADE_HEAD:
#     BBOX_REG_WEIGHTS:
#     - - 10.0
#       - 10.0
#       - 5.0
#       - 5.0
#     - - 20.0
#       - 20.0
#       - 10.0
#       - 10.0
#     - - 30.0
#       - 30.0
#       - 15.0
#       - 15.0
#     IOUS:
#     - 0.5
#     - 0.6
#     - 0.7
#   ROI_BOX_HEAD:
#     BBOX_REG_LOSS_TYPE: smooth_l1
#     BBOX_REG_LOSS_WEIGHT: 1.0
#     BBOX_REG_WEIGHTS:
#     - 10.0
#     - 10.0
#     - 5.0
#     - 5.0
#     CLS_AGNOSTIC_BBOX_REG: true
#     CONV_DIM: 256
#     FC_DIM: 1024
#     NAME: FastRCNNConvFCHead
#     NORM: ''
#     NUM_CONV: 0
#     NUM_FC: 2
#     POOLER_RESOLUTION: 7
#     POOLER_SAMPLING_RATIO: 0
#     POOLER_TYPE: ROIAlignV2
#     SMOOTH_L1_BETA: 0.0
#     TRAIN_ON_PRED_BOXES: false
#   ROI_HEADS:
#     BATCH_SIZE_PER_IMAGE: 512
#     IN_FEATURES:
#     - p2
#     - p3
#     - p4
#     - p5
#     IOU_LABELS:
#     - 0
#     - 1
#     IOU_THRESHOLDS:
#     - 0.5
#     NAME: CascadeROIHeads
#     NMS_THRESH_TEST: 0.5
#     NUM_CLASSES: 10
#     POSITIVE_FRACTION: 0.25
#     PROPOSAL_APPEND_GT: true
#     SCORE_THRESH_TEST: 0.05
#   ROI_KEYPOINT_HEAD:
#     CONV_DIMS:
#     - 512
#     - 512
#     - 512
#     - 512
#     - 512
#     - 512
#     - 512
#     - 512
#     LOSS_WEIGHT: 1.0
#     MIN_KEYPOINTS_PER_IMAGE: 1
#     NAME: KRCNNConvDeconvUpsampleHead
#     NORMALIZE_LOSS_BY_VISIBLE_KEYPOINTS: true
#     NUM_KEYPOINTS: 17
#     POOLER_RESOLUTION: 14
#     POOLER_SAMPLING_RATIO: 0
#     POOLER_TYPE: ROIAlignV2
#   ROI_MASK_HEAD:
#     CLS_AGNOSTIC_MASK: false
#     CONV_DIM: 256
#     NAME: MaskRCNNConvUpsampleHead
#     NORM: ''
#     NUM_CONV: 4
#     POOLER_RESOLUTION: 14
#     POOLER_SAMPLING_RATIO: 0
#     POOLER_TYPE: ROIAlignV2
#   RPN:
#     BATCH_SIZE_PER_IMAGE: 256
#     BBOX_REG_LOSS_TYPE: smooth_l1
#     BBOX_REG_LOSS_WEIGHT: 1.0
#     BBOX_REG_WEIGHTS:
#     - 1.0
#     - 1.0
#     - 1.0
#     - 1.0
#     BOUNDARY_THRESH: -1
#     CONV_DIMS:
#     - -1
#     HEAD_NAME: StandardRPNHead
#     IN_FEATURES:
#     - p2
#     - p3
#     - p4
#     - p5
#     - p6
#     IOU_LABELS:
#     - 0
#     - -1
#     - 1
#     IOU_THRESHOLDS:
#     - 0.3
#     - 0.7
#     LOSS_WEIGHT: 1.0
#     NMS_THRESH: 0.7
#     POSITIVE_FRACTION: 0.5
#     POST_NMS_TOPK_TEST: 1000
#     POST_NMS_TOPK_TRAIN: 2000
#     PRE_NMS_TOPK_TEST: 1000
#     PRE_NMS_TOPK_TRAIN: 2000
#     SMOOTH_L1_BETA: 0.0
#   SEM_SEG_HEAD:
#     COMMON_STRIDE: 4
#     CONVS_DIM: 128
#     IGNORE_VALUE: 255
#     IN_FEATURES:
#     - p2
#     - p3
#     - p4
#     - p5
#     LOSS_WEIGHT: 1.0
#     NAME: SemSegFPNHead
#     NORM: GN
#     NUM_CLASSES: 10
#   VIT:
#     DROP_PATH: 0.1
#     IMG_SIZE:
#     - 224
#     - 224
#     NAME: layoutlmv3_base
#     OUT_FEATURES:
#     - layer3
#     - layer5
#     - layer7
#     - layer11
#     POS_TYPE: abs
#   WEIGHTS:
# OUTPUT_DIR:
# SCIHUB_DATA_DIR_TRAIN: ~/publaynet/layout_scihub/train
# SEED: 42
# SOLVER:
#   AMP:
#     ENABLED: true
#   BACKBONE_MULTIPLIER: 1.0
#   BASE_LR: 0.0002
#   BIAS_LR_FACTOR: 1.0
#   CHECKPOINT_PERIOD: 2000
#   CLIP_GRADIENTS:
#     CLIP_TYPE: full_model
#     CLIP_VALUE: 1.0
#     ENABLED: true
#     NORM_TYPE: 2.0
#   GAMMA: 0.1
#   GRADIENT_ACCUMULATION_STEPS: 1
#   IMS_PER_BATCH: 32
#   LR_SCHEDULER_NAME: WarmupCosineLR
#   MAX_ITER: 20000
#   MOMENTUM: 0.9
#   NESTEROV: false
#   OPTIMIZER: ADAMW
#   REFERENCE_WORLD_SIZE: 0
#   STEPS:
#   - 10000
#   WARMUP_FACTOR: 0.01
#   WARMUP_ITERS: 333
#   WARMUP_METHOD: linear
#   WEIGHT_DECAY: 0.05
#   WEIGHT_DECAY_BIAS: null
#   WEIGHT_DECAY_NORM: 0.0
# TEST:
#   AUG:
#     ENABLED: false
#     FLIP: true
#     MAX_SIZE: 4000
#     MIN_SIZES:
#     - 400
#     - 500
#     - 600
#     - 700
#     - 800
#     - 900
#     - 1000
#     - 1100
#     - 1200
#   DETECTIONS_PER_IMAGE: 100
#   EVAL_PERIOD: 1000
#   EXPECTED_RESULTS: []
#   KEYPOINT_OKS_SIGMAS: []
#   PRECISE_BN:
#     ENABLED: false
#     NUM_ITER: 200
# VERSION: 2
# VIS_PERIOD: 0
#
# [08/30 09:47:24 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from /content/PDF-Extract-Kit/models/Layout/model_final.pth ...
# [08/30 09:47:24 fvcore.common.checkpoint]: [Checkpointer] Loading from /content/PDF-Extract-Kit/models/Layout/model_final.pth ...
# 2024-08-30 09:47:27.552 | INFO     | magic_pdf.model.pdf_extract_kit:__init__:148 - DocAnalysis init done!
# 2024-08-30 09:47:27.553 | INFO     | magic_pdf.model.doc_analyze_by_custom_model:custom_model_init:98 - model init cost: 58.544310569763184
# 2024-08-30 09:47:30.869 | INFO     | magic_pdf.model.pdf_extract_kit:__call__:159 - layout detection cost: 2.86
#
# 0: 1888x1408 1 embedding, 243.9ms
# Speed: 51.0ms preprocess, 243.9ms inference, 2.7ms postprocess per image at shape (1, 3, 1888, 1408)
# 2024-08-30 09:47:32.871 | INFO     | magic_pdf.model.pdf_extract_kit:__call__:189 - formula nums: 1, mfr time: 0.75
# 2024-08-30 09:47:33.747 | INFO     | magic_pdf.model.pdf_extract_kit:__call__:159 - layout detection cost: 0.87
#
# 0: 1888x1408 2 embeddings, 233.3ms
# Speed: 16.1ms preprocess, 233.3ms inference, 2.4ms postprocess per image at shape (1, 3, 1888, 1408)
# 2024-08-30 09:47:34.404 | INFO     | magic_pdf.model.pdf_extract_kit:__call__:189 - formula nums: 2, mfr time: 0.4
# 2024-08-30 09:47:35.289 | INFO     | magic_pdf.model.pdf_extract_kit:__call__:159 - layout detection cost: 0.88
#
# 0: 1888x1408 11 embeddings, 2 isolateds, 221.8ms
# Speed: 16.1ms preprocess, 221.8ms inference, 1.7ms postprocess per image at shape (1, 3, 1888, 1408)
# 2024-08-30 09:48:00.977 | INFO     | magic_pdf.model.pdf_extract_kit:__call__:189 - formula nums: 13, mfr time: 25.41
# 2024-08-30 09:48:01.917 | INFO     | magic_pdf.model.pdf_extract_kit:__call__:159 - layout detection cost: 0.94
#
# 0: 1888x1408 8 embeddings, 4 isolateds, 230.7ms
# Speed: 17.8ms preprocess, 230.7ms inference, 1.4ms postprocess per image at shape (1, 3, 1888, 1408)
# 2024-08-30 09:48:34.629 | INFO     | magic_pdf.model.pdf_extract_kit:__call__:189 - formula nums: 12, mfr time: 32.42
# 2024-08-30 09:48:35.527 | INFO     | magic_pdf.model.pdf_extract_kit:__call__:159 - layout detection cost: 0.89
#
# 0: 1888x1408 1 embedding, 1 isolated, 233.9ms
# Speed: 18.3ms preprocess, 233.9ms inference, 1.7ms postprocess per image at shape (1, 3, 1888, 1408)
# 2024-08-30 09:48:39.212 | INFO     | magic_pdf.model.pdf_extract_kit:__call__:189 - formula nums: 2, mfr time: 3.42
# 2024-08-30 09:48:40.232 | INFO     | magic_pdf.model.pdf_extract_kit:__call__:159 - layout detection cost: 1.01
#
# 0: 1888x1408 2 embeddings, 234.6ms
# Speed: 22.7ms preprocess, 234.6ms inference, 2.4ms postprocess per image at shape (1, 3, 1888, 1408)
# 2024-08-30 09:48:41.086 | INFO     | magic_pdf.model.pdf_extract_kit:__call__:189 - formula nums: 2, mfr time: 0.58
# 2024-08-30 09:48:42.057 | INFO     | magic_pdf.model.pdf_extract_kit:__call__:159 - layout detection cost: 0.97
#
# 0: 1888x1408 10 embeddings, 237.5ms
# Speed: 23.1ms preprocess, 237.5ms inference, 1.6ms postprocess per image at shape (1, 3, 1888, 1408)
# 2024-08-30 09:48:43.233 | INFO     | magic_pdf.model.pdf_extract_kit:__call__:189 - formula nums: 10, mfr time: 0.88
# 2024-08-30 09:48:44.136 | INFO     | magic_pdf.model.pdf_extract_kit:__call__:159 - layout detection cost: 0.9
#
# 0: 1888x1408 4 embeddings, 243.0ms
# Speed: 15.7ms preprocess, 243.0ms inference, 1.5ms postprocess per image at shape (1, 3, 1888, 1408)
# 2024-08-30 09:48:44.962 | INFO     | magic_pdf.model.pdf_extract_kit:__call__:189 - formula nums: 4, mfr time: 0.55
# 2024-08-30 09:48:45.860 | INFO     | magic_pdf.model.pdf_extract_kit:__call__:159 - layout detection cost: 0.89
#
# 0: 1888x1408 1 embedding, 243.6ms
# Speed: 15.6ms preprocess, 243.6ms inference, 1.6ms postprocess per image at shape (1, 3, 1888, 1408)
# 2024-08-30 09:48:46.338 | INFO     | magic_pdf.model.pdf_extract_kit:__call__:189 - formula nums: 1, mfr time: 0.21
# 2024-08-30 09:48:47.225 | INFO     | magic_pdf.model.pdf_extract_kit:__call__:159 - layout detection cost: 0.88
#
# 0: 1888x1408 1 embedding, 244.4ms
# Speed: 15.5ms preprocess, 244.4ms inference, 1.7ms postprocess per image at shape (1, 3, 1888, 1408)
# 2024-08-30 09:48:47.791 | INFO     | magic_pdf.model.pdf_extract_kit:__call__:189 - formula nums: 1, mfr time: 0.3
# 2024-08-30 09:48:48.685 | INFO     | magic_pdf.model.pdf_extract_kit:__call__:159 - layout detection cost: 0.89
#
# 0: 1888x1408 (no detections), 253.2ms
# Speed: 15.8ms preprocess, 253.2ms inference, 0.8ms postprocess per image at shape (1, 3, 1888, 1408)
# 2024-08-30 09:48:48.957 | INFO     | magic_pdf.model.pdf_extract_kit:__call__:189 - formula nums: 0, mfr time: 0.0
# 2024-08-30 09:48:49.855 | INFO     | magic_pdf.model.pdf_extract_kit:__call__:159 - layout detection cost: 0.89
#
# 0: 1888x1408 (no detections), 252.8ms
# Speed: 16.3ms preprocess, 252.8ms inference, 0.7ms postprocess per image at shape (1, 3, 1888, 1408)
# 2024-08-30 09:48:50.126 | INFO     | magic_pdf.model.pdf_extract_kit:__call__:189 - formula nums: 0, mfr time: 0.0
# 2024-08-30 09:48:50.998 | INFO     | magic_pdf.model.pdf_extract_kit:__call__:159 - layout detection cost: 0.87
#
# 0: 1888x1408 (no detections), 246.5ms
# Speed: 15.4ms preprocess, 246.5ms inference, 0.9ms postprocess per image at shape (1, 3, 1888, 1408)
# 2024-08-30 09:48:51.263 | INFO     | magic_pdf.model.pdf_extract_kit:__call__:189 - formula nums: 0, mfr time: 0.0
# 2024-08-30 09:48:51.268 | INFO     | magic_pdf.model.doc_analyze_by_custom_model:doc_analyze:124 - doc analyze cost: 83.25580549240112
# 2024-08-30 09:48:51.356 | INFO     | magic_pdf.pdf_parse_union_core:pdf_parse_union:221 - page_id: 0, last_page_cost_time: 0.0
# 2024-08-30 09:48:51.378 | INFO     | magic_pdf.pdf_parse_union_core:pdf_parse_union:221 - page_id: 1, last_page_cost_time: 0.02
# 2024-08-30 09:48:51.463 | INFO     | magic_pdf.pdf_parse_union_core:pdf_parse_union:221 - page_id: 2, last_page_cost_time: 0.08
# 2024-08-30 09:48:51.529 | INFO     | magic_pdf.pdf_parse_union_core:pdf_parse_union:221 - page_id: 3, last_page_cost_time: 0.07
# 2024-08-30 09:48:51.667 | INFO     | magic_pdf.pdf_parse_union_core:pdf_parse_union:221 - page_id: 4, last_page_cost_time: 0.14
# 2024-08-30 09:48:51.886 | INFO     | magic_pdf.pdf_parse_union_core:pdf_parse_union:221 - page_id: 5, last_page_cost_time: 0.22
# 2024-08-30 09:48:52.586 | INFO     | magic_pdf.pdf_parse_union_core:pdf_parse_union:221 - page_id: 6, last_page_cost_time: 0.7
# 2024-08-30 09:48:53.282 | INFO     | magic_pdf.pdf_parse_union_core:pdf_parse_union:221 - page_id: 7, last_page_cost_time: 0.7
# 2024-08-30 09:48:53.580 | INFO     | magic_pdf.pdf_parse_union_core:pdf_parse_union:221 - page_id: 8, last_page_cost_time: 0.3
# 2024-08-30 09:48:53.887 | INFO     | magic_pdf.pdf_parse_union_core:pdf_parse_union:221 - page_id: 9, last_page_cost_time: 0.31
# 2024-08-30 09:48:54.047 | INFO     | magic_pdf.pdf_parse_union_core:pdf_parse_union:221 - page_id: 10, last_page_cost_time: 0.16
# 2024-08-30 09:48:54.131 | INFO     | magic_pdf.pdf_parse_union_core:pdf_parse_union:221 - page_id: 11, last_page_cost_time: 0.08
# 2024-08-30 09:48:54.406 | INFO     | magic_pdf.pdf_parse_union_core:pdf_parse_union:221 - page_id: 12, last_page_cost_time: 0.28
# 2024-08-30 09:48:54.734 | INFO     | magic_pdf.para.para_split_v2:para_split:764 - 连接了第1页和第2页的段落
# 2024-08-30 09:48:54.735 | INFO     | magic_pdf.para.para_split_v2:para_split:764 - 连接了第9页和第10页的段落
# 2024-08-30 09:48:54.735 | INFO     | magic_pdf.para.para_split_v2:para_split:764 - 连接了第10页和第11页的段落
# 2024-08-30 09:48:57.141 | INFO     | magic_pdf.pipe.UNIPipe:pipe_mk_markdown:48 - uni_pipe mk mm_markdown finished
# 2024-08-30 09:48:57.291 | INFO     | magic_pdf.pipe.UNIPipe:pipe_mk_uni_format:43 - uni_pipe mk content list finished
# 2024-08-30 09:48:57.291 | INFO     | magic_pdf.tools.common:do_parse:119 - local output dir is output/spans/auto
# 2024-08-30 09:49:04.931 | INFO     | magic_pdf.libs.pdf_check:detect_invalid_chars:57 - cid_count: 9, text_len: 31504, cid_chars_radio: 0.00028616852146263913
# 2024-08-30 09:49:19.380 | INFO     | magic_pdf.model.pdf_extract_kit:__init__:111 - DocAnalysis init, this may take some times. apply_layout: True, apply_formula: True, apply_ocr: False, apply_table: False
# 2024-08-30 09:49:19.380 | INFO     | magic_pdf.model.pdf_extract_kit:__init__:119 - using device: cuda
# 2024-08-30 09:49:19.380 | INFO     | magic_pdf.model.pdf_extract_kit:__init__:121 - using models_dir: /content/PDF-Extract-Kit/models
# CustomVisionEncoderDecoderModel init
# CustomMBartForCausalLM init
# CustomMBartDecoder init
# [08/30 09:49:57 detectron2]: Rank of current process: 0. World size: 1
# [08/30 09:49:58 detectron2]: Environment info:
# -------------------------------  -----------------------------------------------------------------
# sys.platform                     linux
# Python                           3.10.12 (main, Jul 29 2024, 16:56:48) [GCC 11.4.0]
# numpy                            1.26.3
# detectron2                       0.6 @/usr/local/lib/python3.10/dist-packages/detectron2
# Compiler                         GCC 11.4
# CUDA compiler                    not available
# DETECTRON2_ENV_MODULE            <not set>
# ...
#   - CuDNN 8.7
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.8, CUDNN_VERSION=8.7.0, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=0 -fabi-version=11 -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-stringop-overflow -Wsuggest-override -Wno-psabi -Wno-error=pedantic -Wno-error=old-style-cast -Wno-missing-braces -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_VERSION=2.3.1, USE_CUDA=ON, USE_CUDNN=ON, USE_CUSPARSELT=1, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_GLOO=ON, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=1, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF, USE_ROCM_KERNEL_ASSERT=OFF,
#
# [08/30 09:57:09 detectron2]: Command line arguments: {'config_file': '/usr/local/lib/python3.10/dist-packages/magic_pdf/resources/model_config/layoutlmv3/layoutlmv3_base_inference.yaml', 'resume': False, 'eval_only': False, 'num_gpus': 1, 'num_machines': 1, 'machine_rank': 0, 'dist_url': 'tcp://127.0.0.1:57823', 'opts': ['MODEL.WEIGHTS', '/content/PDF-Extract-Kit/models/Layout/model_final.pth']}
# [08/30 09:57:09 detectron2]: Contents of args.config_file=/usr/local/lib/python3.10/dist-packages/magic_pdf/resources/model_config/layoutlmv3/layoutlmv3_base_inference.yaml:
# AUG:
#   DETR: true
# CACHE_DIR: ~/cache/huggingface
# CUDNN_BENCHMARK: false
# DATALOADER:
#   ASPECT_RATIO_GROUPING: true
#   FILTER_EMPTY_ANNOTATIONS: false
#   NUM_WORKERS: 4
#   REPEAT_THRESHOLD: 0.0
#   SAMPLER_TRAIN: TrainingSampler
# DATASETS:
#   PRECOMPUTED_PROPOSAL_TOPK_TEST: 1000
#   PRECOMPUTED_PROPOSAL_TOPK_TRAIN: 2000
#   PROPOSAL_FILES_TEST: []
#   PROPOSAL_FILES_TRAIN: []
#   TEST:
#   - scihub_train
#   TRAIN:
#   - scihub_train
# GLOBAL:
#   HACK: 1.0
# ICDAR_DATA_DIR_TEST: ''
# ICDAR_DATA_DIR_TRAIN: ''
# INPUT:
#   CROP:
#     ENABLED: true
#     SIZE:
#     - 384
#     - 600
#     TYPE: absolute_range
#   FORMAT: RGB
#   MASK_FORMAT: polygon
#   MAX_SIZE_TEST: 1333
#   MAX_SIZE_TRAIN: 1333
#   MIN_SIZE_TEST: 800
#   MIN_SIZE_TRAIN:
#   - 480
#   - 512
#   - 544
#   - 576
#   - 608
#   - 640
#   - 672
#   - 704
#   - 736
#   - 768
#   - 800
#   MIN_SIZE_TRAIN_SAMPLING: choice
#   RANDOM_FLIP: horizontal
# MODEL:
#   ANCHOR_GENERATOR:
#     ANGLES:
#     - - -90
#       - 0
#       - 90
#     ASPECT_RATIOS:
#     - - 0.5
#       - 1.0
#       - 2.0
#     NAME: DefaultAnchorGenerator
#     OFFSET: 0.0
#     SIZES:
#     - - 32
#     - - 64
#     - - 128
#     - - 256
#     - - 512
#   BACKBONE:
#     FREEZE_AT: 2
#     NAME: build_vit_fpn_backbone
#   CONFIG_PATH: ''
#   DEVICE: cuda
#   FPN:
#     FUSE_TYPE: sum
#     IN_FEATURES:
#     - layer3
#     - layer5
#     - layer7
#     - layer11
#     NORM: ''
#     OUT_CHANNELS: 256
#   IMAGE_ONLY: true
#   KEYPOINT_ON: false
#   LOAD_PROPOSALS: false
#   MASK_ON: true
#   META_ARCHITECTURE: VLGeneralizedRCNN
#   PANOPTIC_FPN:
#     COMBINE:
#       ENABLED: true
#       INSTANCES_CONFIDENCE_THRESH: 0.5
#       OVERLAP_THRESH: 0.5
#       STUFF_AREA_LIMIT: 4096
#     INSTANCE_LOSS_WEIGHT: 1.0
#   PIXEL_MEAN:
#   - 127.5
#   - 127.5
#   - 127.5
#   PIXEL_STD:
#   - 127.5
#   - 127.5
#   - 127.5
#   PROPOSAL_GENERATOR:
#     MIN_SIZE: 0
#     NAME: RPN
#   RESNETS:
#     DEFORM_MODULATED: false
#     DEFORM_NUM_GROUPS: 1
#     DEFORM_ON_PER_STAGE:
#     - false
#     - false
#     - false
#     - false
#     DEPTH: 50
#     NORM: FrozenBN
#     NUM_GROUPS: 1
#     OUT_FEATURES:
#     - res4
#     RES2_OUT_CHANNELS: 256
#     RES5_DILATION: 1
#     STEM_OUT_CHANNELS: 64
#     STRIDE_IN_1X1: true
#     WIDTH_PER_GROUP: 64
#   RETINANET:
#     BBOX_REG_LOSS_TYPE: smooth_l1
#     BBOX_REG_WEIGHTS:
#     - 1.0
#     - 1.0
#     - 1.0
#     - 1.0
#     FOCAL_LOSS_ALPHA: 0.25
#     FOCAL_LOSS_GAMMA: 2.0
#     IN_FEATURES:
#     - p3
#     - p4
#     - p5
#     - p6
#     - p7
#     IOU_LABELS:
#     - 0
#     - -1
#     - 1
#     IOU_THRESHOLDS:
#     - 0.4
#     - 0.5
#     NMS_THRESH_TEST: 0.5
#     NORM: ''
#     NUM_CLASSES: 10
#     NUM_CONVS: 4
#     PRIOR_PROB: 0.01
#     SCORE_THRESH_TEST: 0.05
#     SMOOTH_L1_LOSS_BETA: 0.1
#     TOPK_CANDIDATES_TEST: 1000
#   ROI_BOX_CASCADE_HEAD:
#     BBOX_REG_WEIGHTS:
#     - - 10.0
#       - 10.0
#       - 5.0
#       - 5.0
#     - - 20.0
#       - 20.0
#       - 10.0
#       - 10.0
#     - - 30.0
#       - 30.0
#       - 15.0
#       - 15.0
#     IOUS:
#     - 0.5
#     - 0.6
#     - 0.7
#   ROI_BOX_HEAD:
#     BBOX_REG_LOSS_TYPE: smooth_l1
#     BBOX_REG_LOSS_WEIGHT: 1.0
#     BBOX_REG_WEIGHTS:
#     - 10.0
#     - 10.0
#     - 5.0
#     - 5.0
#     CLS_AGNOSTIC_BBOX_REG: true
#     CONV_DIM: 256
#     FC_DIM: 1024
#     NAME: FastRCNNConvFCHead
#     NORM: ''
#     NUM_CONV: 0
#     NUM_FC: 2
#     POOLER_RESOLUTION: 7
#     POOLER_SAMPLING_RATIO: 0
#     POOLER_TYPE: ROIAlignV2
#     SMOOTH_L1_BETA: 0.0
#     TRAIN_ON_PRED_BOXES: false
#   ROI_HEADS:
#     BATCH_SIZE_PER_IMAGE: 512
#     IN_FEATURES:
#     - p2
#     - p3
#     - p4
#     - p5
#     IOU_LABELS:
#     - 0
#     - 1
#     IOU_THRESHOLDS:
#     - 0.5
#     NAME: CascadeROIHeads
#     NMS_THRESH_TEST: 0.5
#     NUM_CLASSES: 10
#     POSITIVE_FRACTION: 0.25
#     PROPOSAL_APPEND_GT: true
#     SCORE_THRESH_TEST: 0.05
#   ROI_KEYPOINT_HEAD:
#     CONV_DIMS:
#     - 512
#     - 512
#     - 512
#     - 512
#     - 512
#     - 512
#     - 512
#     - 512
#     LOSS_WEIGHT: 1.0
#     MIN_KEYPOINTS_PER_IMAGE: 1
#     NAME: KRCNNConvDeconvUpsampleHead
#     NORMALIZE_LOSS_BY_VISIBLE_KEYPOINTS: true
#     NUM_KEYPOINTS: 17
#     POOLER_RESOLUTION: 14
#     POOLER_SAMPLING_RATIO: 0
#     POOLER_TYPE: ROIAlignV2
#   ROI_MASK_HEAD:
#     CLS_AGNOSTIC_MASK: false
#     CONV_DIM: 256
#     NAME: MaskRCNNConvUpsampleHead
#     NORM: ''
#     NUM_CONV: 4
#     POOLER_RESOLUTION: 14
#     POOLER_SAMPLING_RATIO: 0
#     POOLER_TYPE: ROIAlignV2
#   RPN:
#     BATCH_SIZE_PER_IMAGE: 256
#     BBOX_REG_LOSS_TYPE: smooth_l1
#     BBOX_REG_LOSS_WEIGHT: 1.0
#     BBOX_REG_WEIGHTS:
#     - 1.0
#     - 1.0
#     - 1.0
#     - 1.0
#     BOUNDARY_THRESH: -1
#     CONV_DIMS:
#     - -1
#     HEAD_NAME: StandardRPNHead
#     IN_FEATURES:
#     - p2
#     - p3
#     - p4
#     - p5
#     - p6
#     IOU_LABELS:
#     - 0
#     - -1
#     - 1
#     IOU_THRESHOLDS:
#     - 0.3
#     - 0.7
#     LOSS_WEIGHT: 1.0
#     NMS_THRESH: 0.7
#     POSITIVE_FRACTION: 0.5
#     POST_NMS_TOPK_TEST: 1000
#     POST_NMS_TOPK_TRAIN: 2000
#     PRE_NMS_TOPK_TEST: 1000
#     PRE_NMS_TOPK_TRAIN: 2000
#     SMOOTH_L1_BETA: 0.0
#   SEM_SEG_HEAD:
#     COMMON_STRIDE: 4
#     CONVS_DIM: 128
#     IGNORE_VALUE: 255
#     IN_FEATURES:
#     - p2
#     - p3
#     - p4
#     - p5
#     LOSS_WEIGHT: 1.0
#     NAME: SemSegFPNHead
#     NORM: GN
#     NUM_CLASSES: 10
#   VIT:
#     DROP_PATH: 0.1
#     IMG_SIZE:
#     - 224
#     - 224
#     NAME: layoutlmv3_base
#     OUT_FEATURES:
#     - layer3
#     - layer5
#     - layer7
#     - layer11
#     POS_TYPE: abs
#   WEIGHTS:
# OUTPUT_DIR:
# SCIHUB_DATA_DIR_TRAIN: ~/publaynet/layout_scihub/train
# SEED: 42
# SOLVER:
#   AMP:
#     ENABLED: true
#   BACKBONE_MULTIPLIER: 1.0
#   BASE_LR: 0.0002
#   BIAS_LR_FACTOR: 1.0
#   CHECKPOINT_PERIOD: 2000
#   CLIP_GRADIENTS:
#     CLIP_TYPE: full_model
#     CLIP_VALUE: 1.0
#     ENABLED: true
#     NORM_TYPE: 2.0
#   GAMMA: 0.1
#   GRADIENT_ACCUMULATION_STEPS: 1
#   IMS_PER_BATCH: 32
#   LR_SCHEDULER_NAME: WarmupCosineLR
#   MAX_ITER: 20000
#   MOMENTUM: 0.9
#   NESTEROV: false
#   OPTIMIZER: ADAMW
#   REFERENCE_WORLD_SIZE: 0
#   STEPS:
#   - 10000
#   WARMUP_FACTOR: 0.01
#   WARMUP_ITERS: 333
#   WARMUP_METHOD: linear
#   WEIGHT_DECAY: 0.05
#   WEIGHT_DECAY_BIAS: null
#   WEIGHT_DECAY_NORM: 0.0
# TEST:
#   AUG:
#     ENABLED: false
#     FLIP: true
#     MAX_SIZE: 4000
#     MIN_SIZES:
#     - 400
#     - 500
#     - 600
#     - 700
#     - 800
#     - 900
#     - 1000
#     - 1100
#     - 1200
#   DETECTIONS_PER_IMAGE: 100
#   EVAL_PERIOD: 1000
#   EXPECTED_RESULTS: []
#   KEYPOINT_OKS_SIGMAS: []
#   PRECISE_BN:
#     ENABLED: false
#     NUM_ITER: 200
# VERSION: 2
# VIS_PERIOD: 0
#
# [08/30 09:57:12 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from /content/PDF-Extract-Kit/models/Layout/model_final.pth ...
# [08/30 09:57:12 fvcore.common.checkpoint]: [Checkpointer] Loading from /content/PDF-Extract-Kit/models/Layout/model_final.pth ...
# 2024-08-30 09:57:15.142 | INFO     | magic_pdf.model.pdf_extract_kit:__init__:148 - DocAnalysis init done!
# 2024-08-30 09:57:15.143 | INFO     | magic_pdf.model.doc_analyze_by_custom_model:custom_model_init:98 - model init cost: 58.46422743797302
# 2024-08-30 09:57:18.300 | INFO     | magic_pdf.model.pdf_extract_kit:__call__:159 - layout detection cost: 2.81
#
# 0: 1888x1408 7 embeddings, 251.6ms
# Speed: 53.7ms preprocess, 251.6ms inference, 2.4ms postprocess per image at shape (1, 3, 1888, 1408)
# 2024-08-30 09:57:20.559 | INFO     | magic_pdf.model.pdf_extract_kit:__call__:189 - formula nums: 7, mfr time: 0.97
# 2024-08-30 09:57:21.438 | INFO     | magic_pdf.model.pdf_extract_kit:__call__:159 - layout detection cost: 0.87
#
# 0: 1888x1408 3 embeddings, 244.7ms
# Speed: 15.4ms preprocess, 244.7ms inference, 2.0ms postprocess per image at shape (1, 3, 1888, 1408)
# 2024-08-30 09:57:22.205 | INFO     | magic_pdf.model.pdf_extract_kit:__call__:189 - formula nums: 3, mfr time: 0.49
# 2024-08-30 09:57:23.109 | INFO     | magic_pdf.model.pdf_extract_kit:__call__:159 - layout detection cost: 0.9
#
# 0: 1888x1408 18 embeddings, 2 isolateds, 243.5ms
# Speed: 15.4ms preprocess, 243.5ms inference, 1.6ms postprocess per image at shape (1, 3, 1888, 1408)
# 2024-08-30 09:57:25.241 | INFO     | magic_pdf.model.pdf_extract_kit:__call__:189 - formula nums: 20, mfr time: 1.82
# 2024-08-30 09:57:26.170 | INFO     | magic_pdf.model.pdf_extract_kit:__call__:159 - layout detection cost: 0.92
#
# 0: 1888x1408 32 embeddings, 4 isolateds, 233.2ms
# Speed: 23.7ms preprocess, 233.2ms inference, 2.0ms postprocess per image at shape (1, 3, 1888, 1408)
# 2024-08-30 09:57:30.369 | INFO     | magic_pdf.model.pdf_extract_kit:__call__:189 - formula nums: 36, mfr time: 3.79
# 2024-08-30 09:57:31.305 | INFO     | magic_pdf.model.pdf_extract_kit:__call__:159 - layout detection cost: 0.93
#
# 0: 1888x1408 7 embeddings, 1 isolated, 233.6ms
# Speed: 16.1ms preprocess, 233.6ms inference, 1.6ms postprocess per image at shape (1, 3, 1888, 1408)
# 2024-08-30 09:57:33.509 | INFO     | magic_pdf.model.pdf_extract_kit:__call__:189 - formula nums: 8, mfr time: 1.92
# 2024-08-30 09:57:34.441 | INFO     | magic_pdf.model.pdf_extract_kit:__call__:159 - layout detection cost: 0.93
#
# 0: 1888x1408 6 embeddings, 234.5ms
# Speed: 16.9ms preprocess, 234.5ms inference, 2.1ms postprocess per image at shape (1, 3, 1888, 1408)
# 2024-08-30 09:57:34.947 | INFO     | magic_pdf.model.pdf_extract_kit:__call__:189 - formula nums: 6, mfr time: 0.23
# 2024-08-30 09:57:35.844 | INFO     | magic_pdf.model.pdf_extract_kit:__call__:159 - layout detection cost: 0.89
#
# 0: 1888x1408 20 embeddings, 246.4ms
# Speed: 15.4ms preprocess, 246.4ms inference, 1.7ms postprocess per image at shape (1, 3, 1888, 1408)
# 2024-08-30 09:57:36.951 | INFO     | magic_pdf.model.pdf_extract_kit:__call__:189 - formula nums: 20, mfr time: 0.79
# 2024-08-30 09:57:37.847 | INFO     | magic_pdf.model.pdf_extract_kit:__call__:159 - layout detection cost: 0.89
#
# 0: 1888x1408 7 embeddings, 242.6ms
# Speed: 15.4ms preprocess, 242.6ms inference, 1.5ms postprocess per image at shape (1, 3, 1888, 1408)
# 2024-08-30 09:57:38.518 | INFO     | magic_pdf.model.pdf_extract_kit:__call__:189 - formula nums: 7, mfr time: 0.39
# 2024-08-30 09:57:39.415 | INFO     | magic_pdf.model.pdf_extract_kit:__call__:159 - layout detection cost: 0.89
#
# 0: 1888x1408 15 embeddings, 243.0ms
# Speed: 16.3ms preprocess, 243.0ms inference, 1.5ms postprocess per image at shape (1, 3, 1888, 1408)
# 2024-08-30 09:57:40.420 | INFO     | magic_pdf.model.pdf_extract_kit:__call__:189 - formula nums: 15, mfr time: 0.7
# 2024-08-30 09:57:41.379 | INFO     | magic_pdf.model.pdf_extract_kit:__call__:159 - layout detection cost: 0.95
#
# 0: 1888x1408 1 embedding, 242.0ms
# Speed: 23.6ms preprocess, 242.0ms inference, 2.2ms postprocess per image at shape (1, 3, 1888, 1408)
# 2024-08-30 09:57:41.996 | INFO     | magic_pdf.model.pdf_extract_kit:__call__:189 - formula nums: 1, mfr time: 0.34
# 2024-08-30 09:57:42.963 | INFO     | magic_pdf.model.pdf_extract_kit:__call__:159 - layout detection cost: 0.96
#
# 0: 1888x1408 4 embeddings, 239.2ms
# Speed: 33.6ms preprocess, 239.2ms inference, 2.0ms postprocess per image at shape (1, 3, 1888, 1408)
# 2024-08-30 09:57:43.948 | INFO     | magic_pdf.model.pdf_extract_kit:__call__:189 - formula nums: 4, mfr time: 0.69
# 2024-08-30 09:57:44.905 | INFO     | magic_pdf.model.pdf_extract_kit:__call__:159 - layout detection cost: 0.95
#
# 0: 1888x1408 1 embedding, 250.2ms
# Speed: 16.4ms preprocess, 250.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1888, 1408)
# 2024-08-30 09:57:45.548 | INFO     | magic_pdf.model.pdf_extract_kit:__call__:189 - formula nums: 1, mfr time: 0.37
# 2024-08-30 09:57:46.424 | INFO     | magic_pdf.model.pdf_extract_kit:__call__:159 - layout detection cost: 0.87
#
# 0: 1888x1408 (no detections), 242.5ms
# Speed: 15.2ms preprocess, 242.5ms inference, 0.7ms postprocess per image at shape (1, 3, 1888, 1408)
# 2024-08-30 09:57:46.684 | INFO     | magic_pdf.model.pdf_extract_kit:__call__:189 - formula nums: 0, mfr time: 0.0
# 2024-08-30 09:57:46.688 | INFO     | magic_pdf.model.doc_analyze_by_custom_model:doc_analyze:124 - doc analyze cost: 31.2015700340271
# 2024-08-30 09:57:46.772 | INFO     | magic_pdf.pdf_parse_union_core:pdf_parse_union:221 - page_id: 0, last_page_cost_time: 0.0
# 2024-08-30 09:57:46.796 | INFO     | magic_pdf.pdf_parse_union_core:pdf_parse_union:221 - page_id: 1, last_page_cost_time: 0.02
# 2024-08-30 09:57:46.871 | INFO     | magic_pdf.pdf_parse_union_core:pdf_parse_union:221 - page_id: 2, last_page_cost_time: 0.08
# 2024-08-30 09:57:46.942 | INFO     | magic_pdf.pdf_parse_union_core:pdf_parse_union:221 - page_id: 3, last_page_cost_time: 0.07
# 2024-08-30 09:57:47.071 | INFO     | magic_pdf.pdf_parse_union_core:pdf_parse_union:221 - page_id: 4, last_page_cost_time: 0.13
# 2024-08-30 09:57:47.264 | INFO     | magic_pdf.pdf_parse_union_core:pdf_parse_union:221 - page_id: 5, last_page_cost_time: 0.19
# 2024-08-30 09:57:47.769 | INFO     | magic_pdf.pdf_parse_union_core:pdf_parse_union:221 - page_id: 6, last_page_cost_time: 0.5
# 2024-08-30 09:57:47.861 | INFO     | magic_pdf.pdf_parse_union_core:pdf_parse_union:221 - page_id: 7, last_page_cost_time: 0.09
# 2024-08-30 09:57:48.036 | INFO     | magic_pdf.pdf_parse_union_core:pdf_parse_union:221 - page_id: 8, last_page_cost_time: 0.18
# 2024-08-30 09:57:48.193 | INFO     | magic_pdf.pdf_parse_union_core:pdf_parse_union:221 - page_id: 9, last_page_cost_time: 0.16
# 2024-08-30 09:57:48.293 | INFO     | magic_pdf.pdf_parse_union_core:pdf_parse_union:221 - page_id: 10, last_page_cost_time: 0.1
# 2024-08-30 09:57:48.347 | INFO     | magic_pdf.pdf_parse_union_core:pdf_parse_union:221 - page_id: 11, last_page_cost_time: 0.05
# 2024-08-30 09:57:48.400 | INFO     | magic_pdf.pdf_parse_union_core:pdf_parse_union:221 - page_id: 12, last_page_cost_time: 0.05
# 2024-08-30 09:57:48.570 | INFO     | magic_pdf.para.para_split_v2:para_split:764 - 连接了第1页和第2页的段落
# 2024-08-30 09:57:48.570 | INFO     | magic_pdf.para.para_split_v2:para_split:764 - 连接了第9页和第10页的段落
# 2024-08-30 09:57:48.570 | INFO     | magic_pdf.para.para_split_v2:para_split:764 - 连接了第10页和第11页的段落
# 2024-08-30 09:57:48.570 | INFO     | magic_pdf.para.para_split_v2:__connect_middle_align_text:682 - 0.498016357421875
# 2024-08-30 09:57:50.087 | INFO     | magic_pdf.pipe.UNIPipe:pipe_mk_markdown:48 - uni_pipe mk mm_markdown finished
# 2024-08-30 09:57:50.718 | INFO     | magic_pdf.pipe.UNIPipe:pipe_mk_uni_format:43 - uni_pipe mk content list finished
# 2024-08-30 09:57:50.718 | INFO     | magic_pdf.tools.common:do_parse:119 - local output dir is output/demo1/auto

# %% [markdown]
# ### 2.2API

# %% [markdown]
# #### **Simplest Convertion**

# %%
"""
convert pdf to markdown and text
"""
from magic_pdf.rw.DiskReaderWriter import DiskReaderWriter
from magic_pdf.pipe.UNIPipe import UNIPipe
import os
pdf_path = "demo1.pdf"
output_dir = "output_api/"
pdf_name = os.path.basename(pdf_path).split(".")[0]
output_path = os.path.join(output_dir, pdf_name)
output_image_path = os.path.join(output_path, 'images')


image_writer = DiskReaderWriter(output_image_path)
image_dir = str(os.path.basename(output_image_path))
jso_useful_key = {"_pdf_type": "", "model_list": []}
pdf_bytes = open(pdf_path, "rb").read()
pipe = UNIPipe(pdf_bytes, jso_useful_key, image_writer)
pipe.pipe_classify()
pipe.pipe_analyze()
pipe.pipe_parse()
md_content = pipe.pipe_mk_markdown(image_dir, drop_mode="none")
print(md_content)

# %% [markdown]
# #### **Convertion with middle details**

# %%
"""
convert pdf and save middle.json model.json
"""
import copy
import json
def json_md_dump(
        pipe,
        md_writer,
        pdf_name,
        content_list,
        md_content,
):
    # 写入模型结果到 model.json
    orig_model_list = copy.deepcopy(pipe.model_list)
    md_writer.write(
        content=json.dumps(orig_model_list, ensure_ascii=False, indent=4),
        path=f"{pdf_name}_model.json"
    )

    # 写入中间结果到 middle.json
    md_writer.write(
        content=json.dumps(pipe.pdf_mid_data, ensure_ascii=False, indent=4),
        path=f"{pdf_name}_middle.json"
    )

    # text文本结果写入到 conent_list.json
    md_writer.write(
        content=json.dumps(content_list, ensure_ascii=False, indent=4),
        path=f"{pdf_name}_content_list.json"
    )

    # 写入结果到 .md 文件中
    md_writer.write(
        content=md_content,
        path=f"{pdf_name}.md"
    )



md_writer = DiskReaderWriter(output_path)
image_path_parent = os.path.basename(output_image_path)
content_list = pipe.pipe_mk_uni_format(image_path_parent, drop_mode="none")
json_md_dump(pipe, md_writer, pdf_name, content_list, md_content)
# Out:
# 2024-08-30 10:36:40.967 | INFO     | magic_pdf.pipe.UNIPipe:pipe_mk_uni_format:43 - uni_pipe mk content list finished

# %% [markdown]
# #### **Produce Equtation Results and draw bounding boxes with number**

# %%
"""
detect and recognize equations from a pdf page
"""

import fitz  # PyMuPDF
import matplotlib.pyplot as plt


import fitz  # PyMuPDF
import matplotlib.pyplot as plt
import numpy as np
def show_pdf(page0, page1):

  pix1 = page0.get_pixmap()
  img_array1 = np.frombuffer(pix1.samples, dtype=np.uint8).reshape(pix1.height, pix1.width, pix1.n)

  # Load and render the second page
  pix2 = page1.get_pixmap()
  img_array2 = np.frombuffer(pix2.samples, dtype=np.uint8).reshape(pix2.height, pix2.width, pix2.n)

  # Create subplots
  fig, axes = plt.subplots(1, 2, figsize=(12, 8))

  # Display the first image
  axes[0].imshow(img_array1)
  axes[0].axis('off')

  # Display the second image
  axes[1].imshow(img_array2)
  axes[1].axis('off')

  plt.tight_layout()
  plt.show()

# %%
"""
output equations in latex and draw bounding boxes with number on a pdf page
"""
from magic_pdf.libs.Constants import CROSS_PAGE
from magic_pdf.libs.commons import fitz  # PyMuPDF
from magic_pdf.libs.ocr_content_type import ContentType, BlockType, CategoryId
from magic_pdf.model.magic_model import MagicModel
from magic_pdf.libs.draw_bbox import draw_bbox_with_number

pdf_info = pipe.pdf_mid_data["pdf_info"]
text_list = []
inline_equation_list = []
interline_equation_list = []
interline_equation_content_list = []
image_list = []
table_list = []
dropped_list = []
next_page_text_list = []
next_page_inline_equation_list = []

def get_span_info(span):
    if span["type"] == ContentType.Text:
        if span.get(CROSS_PAGE, False):
            next_page_text_list.append(span["bbox"])
        else:
            page_text_list.append(span["bbox"])
    elif span["type"] == ContentType.InlineEquation:
        if span.get(CROSS_PAGE, False):
            next_page_inline_equation_list.append(span["bbox"])
        else:
            page_inline_equation_list.append(span["bbox"])
    elif span["type"] == ContentType.InterlineEquation:
        page_interline_equation_list.append(span["bbox"])
        page_interline_equation_content_list.append(span["content"])
    elif span["type"] == ContentType.Image:
        page_image_list.append(span["bbox"])
    elif span["type"] == ContentType.Table:
        page_table_list.append(span["bbox"])

for page in pdf_info:
    page_text_list = []
    page_inline_equation_list = []
    page_interline_equation_list = []
    page_interline_equation_content_list = []
    page_image_list = []
    page_table_list = []
    page_dropped_list = []

    # 将跨页的span放到移动到下一页的列表中
    if len(next_page_text_list) > 0:
        page_text_list.extend(next_page_text_list)
        next_page_text_list.clear()
    if len(next_page_inline_equation_list) > 0:
        page_inline_equation_list.extend(next_page_inline_equation_list)
        next_page_inline_equation_list.clear()

    # 构造dropped_list
    for block in page["discarded_blocks"]:
        if block["type"] == BlockType.Discarded:
            for line in block["lines"]:
                for span in line["spans"]:
                    page_dropped_list.append(span["bbox"])
    dropped_list.append(page_dropped_list)
    # 构造其余useful_list
    for block in page["para_blocks"]:
        if block["type"] in [
            BlockType.Text,
            BlockType.Title,
            BlockType.InterlineEquation,
        ]:
            for line in block["lines"]:
                for span in line["spans"]:
                    get_span_info(span)
        elif block["type"] in [BlockType.Image, BlockType.Table]:
            for sub_block in block["blocks"]:
                for line in sub_block["lines"]:
                    for span in line["spans"]:
                        get_span_info(span)
    text_list.append(page_text_list)
    inline_equation_list.append(page_inline_equation_list)
    interline_equation_list.append(page_interline_equation_list)
    interline_equation_content_list.append(page_interline_equation_content_list)
    image_list.append(page_image_list)
    table_list.append(page_table_list)

# %%
pdf_docs = fitz.open("pdf", pdf_bytes)
page_no = 3
page = pdf_docs[page_no]
draw_bbox_with_number(page_no, interline_equation_list, page, [0, 0, 255], False)
ori_pdf = "demo1.pdf"
# Load and render the first page
ori_page_i = fitz.open(ori_pdf).load_page(page_no)
show_pdf(ori_page_i, page)
for i, equation in enumerate(interline_equation_content_list[page_no]):
  print(f"{i}: {equation}")

# %% [markdown]
# #### **Produce image Results and draw bounding boxes with number**

# %%
pdf_docs = fitz.open("pdf", pdf_bytes)
page_no = 3
page = pdf_docs[page_no]
draw_bbox_with_number(page_no, image_list, page, [0, 0, 255], False)
ori_pdf = "demo1.pdf"
# Load and render the first page
ori_page_i = fitz.open(ori_pdf).load_page(page_no)
show_pdf(ori_page_i, page)

# %% [markdown]
# #### **Produce text Results and draw bounding boxes with number**

# %%
pdf_docs = fitz.open("pdf", pdf_bytes)
page_no = 3
page = pdf_docs[page_no]
draw_bbox_with_number(page_no, text_list, page, [0, 0, 255], False)
ori_pdf = "demo1.pdf"
# Load and render the first page
ori_page_i = fitz.open(ori_pdf).load_page(page_no)
show_pdf(ori_page_i, page)

# %% [markdown]
# #### **Produce Dropped content and draw bounding boxes with number**

# %%
pdf_docs = fitz.open("pdf", pdf_bytes)
page_no = 3
page = pdf_docs[page_no]
draw_bbox_with_number(page_no, dropped_list, page, [0, 0, 255], False)
ori_pdf = "demo1.pdf"
# Load and render the first page
ori_page_i = fitz.open(ori_pdf).load_page(page_no)
show_pdf(ori_page_i, page)
